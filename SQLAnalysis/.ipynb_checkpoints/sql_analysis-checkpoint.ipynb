# %% [markdown]
# # SQL Analysis
# Greg Salmon

# %% [markdown]
# ### Importing pandas and create_engine for SQL Analysis

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### mySQL Login

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# ## Queries

# %% [markdown]
# ### Descriptive Analytics

# %% [markdown]
# The first thing I want to look into is seeing how many instructers there are, as well as their average rating, difficulty, count of ratings, and would retake probability

# %%
# %%sql
# SELECT
#     COUNT(Instructor) AS CountInstructors,
#     ROUND(AVG(Rating), 2) AS AvgRating,
#     ROUND(AVG(Difficulty), 2) AS AvgDifficulty,
#     ROUND(AVG(CountRatings), 2) AS AvgCountRatings,
#     ROUND(AVG(WouldRetake), 2) AS AvgWouldRetake
# FROM rmp_ratings rr;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1 rows affected.
# [(1396, 3.33, 2.52, Decimal('12.79'), 0.74)]

# %% [markdown]
# Something I am interested is the amount of instructors shown. I wonder if Prowl will have a similar amount. I am worried that there may be issues with the correct amount of data passing over.

# %% [markdown]
# I would like to look into the data I scraped from Prowl. Specifically, I want to see how many unique teachers and subjects there are.

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT(InstructorID)) AS CountInstructors,
#     COUNT(DISTINCT(Subject)) AS CountSubjects
# FROM classes c;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1 rows affected.
# [(765, 97)]

# %% [markdown]
# Interesting. Comparing the amount of instructors who are actually teaching a class in prowl to the professors in RMP shows there are significantly more professors in RMP. Two things come to mind:
# 1) RMP does not remove teachers who no longer teach at the school
#
# 2) Teachers may have different names or name changes.
# It may be useful to look into this aspect of the data.

# %% [markdown]
# I think it could be interesting to see if there are any specific meeting days that have a significant higher amount of classes. SQL features used: Aggregate functions, Case Statement

# %%
# %%sql
# SELECT
#     SUM(CASE WHEN MeetingDays = "MWF" THEN 1 ELSE 0 END) AS CountMWF,
#     SUM(CASE WHEN MeetingDays = "MW" THEN 1 ELSE 0 END) AS CountMW,
#     SUM(CASE WHEN MeetingDays = "TT" THEN 1 ELSE 0 END) AS CountTT,
#     SUM(CASE WHEN MeetingDays = "M" THEN 1 ELSE 0 END) AS CountM,
#     SUM(CASE WHEN MeetingDays = "T" THEN 1 ELSE 0 END) AS CountT,
#     SUM(CASE WHEN MeetingDays = "W" THEN 1 ELSE 0 END) AS CountW,
#     SUM(CASE WHEN MeetingDays = "Th" THEN 1 ELSE 0 END) AS CountTh,
#     SUM(CASE WHEN MeetingDays = "F" THEN 1 ELSE 0 END) AS CountF
# FROM classes c;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1 rows affected.
# [(Decimal('243'), Decimal('418'), Decimal('614'), Decimal('238'), Decimal('280'), Decimal('234'), Decimal('196'), Decimal('48'))]

# %% [markdown]
# There is a significant amount of classes meeting on Tuesday and Thursday. This may have an effect on a multitude of things on campus. While this project focuses on specifically rate my professor, it could be interesting to see if moving some of the Tuesday/Thursday classes to other days could alleviate parking. I digress. It is interesting to me to see that there are very few friday classes. I wonder if classes that are required to meet on just one day would have worse reviews due to the long class periods.

# %% [markdown]
# I want to also look at what professors have the most amount of ratings. There may be trends in what college or department gets the most reviews.

# %%
# %%sql
# SELECT
#     Instructor,
#     Department,
#     CountRatings
# FROM rmp_ratings rr
# ORDER BY CountRatings DESC;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1396 rows affected.
# [('Megan Granich', 'Mathematics', 124),
#  ('Jodi Finkel', 'Political Science', 119),
#  ('Michel van Biezen', 'Physics', 104),
#  ('Amir Hussain', 'Theology', 99),
#  ('Karen Ellis', 'Mathematics', 93),
#  ('Michael Foy', 'Psychology', 90),
#  ('Evan Gerstmann', 'Political Science', 87),
#  ('Ralph Quinones', 'Business', 86),
#  ('Cara Anzilotti', 'History', 82),
#  ('Laurie Pintar', 'History', 80),
#  ('Nigel Raab', 'History', 80),
#  ('Wilfredo Flores', 'Mathematics', 78),
#  ('Daniel Smith-Christopher', 'Theology', 76),
#  ('Najwa Al-Qattan', 'History', 73),
#  ('James Devine', 'Economics', 73),
#  ('Renate Thimester', 'Economics', 71),
#  ('Darrin Murray', 'Communication Studies', 71),
#  ('Ronald Barrett', 'Psychology', 69),
#  ('David Zinn', 'Philosophy', 68),
#  ('Dennis Zill', 'Mathematics', 66),
#  ('Tracey Colvin', 'English', 66),
#  ('Allen Gray', 'Business', 65),
#  ('Lambert Doezema', 'Chemistry', 63),
#  ('Arthur Gross-Schafer', 'Business', 62),
#  ('Kala Seal', 'Business', 62),
#  ('Constance Chen', 'History', 62),
#  ('Li Dai', 'International Business', 62),
#  ('Scott Cameron', 'Philosophy', 61),
#  ('Kenneth Rudnick', 'Law', 60),
#  ('Brian Foster', 'American Studies', 58),
#  ('William Shaules', 'Theology', 58),
#  ('Thomas Zachariah', 'Mathematics', 57),
#  ('Michael Tang', 'Fine Arts', 57),
#  ('Megan Barnes', 'English', 56),
#  ('Lev Abolnikov', 'Mathematics', 55),
#  ('Brian Treanor', 'Philosophy', 55),
#  ('David Offenberg', 'Finance', 55),
#  ('Nancy Coster', 'Accounting', 55),
#  ('Brad Stone', 'Philosophy', 54),
#  ('Adam Fingerhut', 'Psychology', 53),
#  ('Dorothea Herreiner', 'Economics', 53),
#  ('Christopher Kaczor', 'Philosophy', 53),
#  ('Fereidoun Jahani', 'Mathematics', 53),
#  ('Amy Woodson-Boulton', 'History', 52),
#  ('Sheilah Jones', 'Theology', 52),
#  ('Linda Leon', 'Business', 52),
#  ('David Sanchez', 'Theology', 51),
#  ('Meric Keskinel', 'Economics', 51),
#  ('Stacy Burns', 'Social Science', 50),
#  ('Richard Rolfs', 'History', 50),
#  ('Mahmoud Nourayi', 'Accounting', 50),
#  ('Peter Hoffman', 'Geography', 50),
#  ('Monica Cabrera', 'Modern Languages & Literatures', 50),
#  ('Joseph Tiedemann', 'History', 49),
#  ('Darnise Martin', 'Theology', 49),
#  ('Jasper Blystone', 'Philosophy', 48),
#  ('Jennifer Pate', 'Economics', 48),
#  ('Wendy Binder', 'Biology', 48),
#  ('Ying Sai', 'Computer Information Systems', 48),
#  ('Annie Liu', 'Marketing', 47),
#  ('Anthony Smulders', 'Science', 47),
#  ('Nicolas Rosenthal', 'History', 47),
#  ('Carl Urbinati', 'Biology', 47),
#  ('Lawrence Jelinek', 'History', 46),
#  ('Jon Saxon', 'Mathematics', 46),
#  ('David Marple', 'Sociology', 46),
#  ('Dionne Bennett', "Women's Studies", 46),
#  ('Cliff Rochlin', 'Economics', 46),
#  ('Ricardo MacHon', 'Psychology', 46),
#  ('Jok Madut Jok', 'History', 46),
#  ('Robert Winsor', 'Business', 46),
#  ('K.J. Peters', 'English', 46),
#  ('Timothy Shanahan', 'Philosophy', 46),
#  ('John Reilly', 'English', 46),
#  ('Therese Edwards', 'Communication Studies', 46),
#  ('Caroline LaMonda', 'Communication Studies', 45),
#  ('Martin Nemoianu', 'Philosophy', 45),
#  ('Michael Brodsky', 'Fine Arts', 45),
#  ('Fred Kiesner', 'Business', 44),
#  ('Dorian Llywelyn', 'Religion', 44),
#  ('Michael Berg', 'Mathematics', 44),
#  ('Patricia Martinez', 'Management', 44),
#  ('William Kinsella', 'Accounting', 44),
#  ('Chun Lee', 'Finance', 44),
#  ('Matt Stefl', 'Marketing', 44),
#  ('Steve Crissanthos', 'History', 43),
#  ('Susan Scheibler', 'Film', 43),
#  ('Juan Mah Y Busch', 'English', 43),
#  ('David Hardy', 'Psychology', 43),
#  ('Saba Soomekh', 'Theology', 43),
#  ('Tania Maync', 'History', 43),
#  ('Blake Mellor', 'Mathematics', 43),
#  ('Nicholas Toghia', 'Business Law', 43),
#  ('Anthony Perron', 'History', 43),
#  ('Jay Kumar', 'Theological Studies', 43),
#  ('Richard Gilbert', 'Psychology', 42),
#  ('Yongsun Paik', 'Business Administration', 42),
#  ('Judy Park', 'English', 42),
#  ('Zaki Eusufzai', 'Economics', 42),
#  ('Tom Dowd', 'Communication Studies', 41),
#  ('Seid Zekavat', 'Economics', 41),
#  ('Connie Weeks', 'Mathematics', 41),
#  ('Alan Cherry', 'Accounting', 41),
#  ('Danielle Borgia', 'American Studies', 41),
#  ('Pat Connolly', 'Communication Studies', 40),
#  ('Lori Bergstrom', 'Communication Studies', 40),
#  ('Judith Foy', 'Psychology', 40),
#  ('Lawrence Tritle', 'History', 40),
#  ('Lowell Herr', 'Philosophy', 40),
#  ('Daniel Speak', 'Philosophy', 40),
#  ('Todd Shoepe', 'Natural Sciences', 40),
#  ('Eric Perl', 'Philosophy', 40),
#  ('Nicole Bouvier-Brown', 'Chemistry', 40),
#  ('Ellen Ensher', 'Management', 40),
#  ('Eric Young', 'Economics', 40),
#  ('Edward Park', 'Ethnic Studies', 39),
#  ('Arik Greenberg', 'Theology', 39),
#  ('Kyra Pearson', 'Communication Studies', 39),
#  ('Natalie Ortiz', 'Mathematics', 39),
#  ('Jeremy McCallum', 'Chemistry', 39),
#  ('Tina Choe', 'Chemistry', 38),
#  ('John Page', 'Engineering', 38),
#  ('Eduardo Morales', 'Mathematics', 38),
#  ('Rene Topalian', 'Biology', 38),
#  ('Teah Goldberg', 'English', 38),
#  ('Martina Ramirez', 'Biology', 38),
#  ('Kathleen Norris', 'Communication Studies', 37),
#  ('John Kochian', 'Communication Studies', 37),
#  ('Michael Grady', 'Mathematics', 37),
#  ('Melissa Nivala', 'Mathematics', 37),
#  ('Jason Baehr', 'Philosophy', 37),
#  ('Stella Oh', 'Ethnic Studies', 37),
#  ('James Faught', 'Sociology', 37),
#  ('Anna Harrison', 'Theology', 37),
#  ('Mark Morelli', 'Philosophy', 36),
#  ('George Dasaro', 'Accounting', 36),
#  ('Paul Lin', 'Ethnic Studies', 36),
#  ('Dexter Blackman', 'History', 36),
#  ('Stuart Ching', 'English', 36),
#  ('Kirstin Noreen', 'Art History', 36),
#  ('Yanping Ma', 'Mathematics', 36),
#  ('Charles Vance', 'Management', 36),
#  ('Cathleen McGrath', 'Business', 36),
#  ('Andrew Forney', 'Computer Science', 36),
#  ('Larry Bernard', 'Psychology', 35),
#  ('Ernesto Sweeney', 'History', 35),
#  ('David Choi', 'Entrepreneurship', 35),
#  ('Andrew Healy', 'Economics', 35),
#  ('Jeffrey Wilson', 'Philosophy', 35),
#  ('Mark Chilingar', 'Psychology', 35),
#  ('Michael Mills', 'Psychology', 35),
#  ('Erika Camacho', 'Mathematics', 34),
#  ('Kristo Gobin', 'Communication Studies', 34),
#  ('Edward Mosteig', 'Mathematics', 34),
#  ('Lucy Wilson', 'English', 33),
#  ('Karenmary Davalos', 'Ethnic Studies', 33),
#  ('M. Cathy McElwain', 'Biology', 33),
#  ('Janie Steckenrider', 'Political Science', 33),
#  ('Elizabeth Drummond', 'History', 33),
#  ('Ying Ying Wang', 'Accounting', 33),
#  ('Scott Delanty', 'Accounting', 33),
#  ('Damon Hines', 'Communication Studies', 33),
#  ('Robert Singleton', 'Economics', 32),
#  ('Rodger Pardee', 'Film', 32),
#  ('Patrick Shanahan', 'Mathematics', 32),
#  ('Gary Sibeck', 'Business', 32),
#  ('Kennedy Wheatly', 'Film', 32),
#  ('Sean Fenton', 'Theater', 32),
#  ('Nyema Guannu', 'Economics', 32),
#  ('Anna Terzyan', 'Economics', 32),
#  ('Matthew Petrusek', 'Theology', 32),
#  ('Robert Simmons', 'Film & Television', 32),
#  ('Cheryl Hertz', 'Biology', 32),
#  ('Alan Falcon', 'Accounting', 31),
#  ('James Fredericks', 'Theology', 31),
#  ('Barbara Rico', 'English', 31),
#  ('Susan Elkinawy', 'Finance', 31),
#  ('Pippa Drennan', 'Biology', 31),
#  ('Sina Kramer', 'Women', 31),
#  ('Nancy Jabbra', "Women's Studies", 30),
#  ('Curtis Bennett', 'Mathematics', 30),
#  ('Al Hayashi', 'Business', 30),
#  ('Sara Lederer', 'Psychology', 30),
#  ('Margarita Ochoa', 'History', 30),
#  ('Thomas Reilly', 'Chemistry', 30),
#  ('Robin Wang', 'Philosophy', 30),
#  ('Mary Breden', 'Music', 29),
#  ('Jeff Sanny', 'Physics', 29),
#  ('Leah Pate', 'English', 29),
#  ('Amy K. Ross', 'English', 29),
#  ('Ron Sorace', 'Mathematics', 29),
#  ('Nora Murphy', 'Psychology', 29),
#  ('Michael Patzia', 'Philosophy', 29),
#  ('James Hanink', 'Philosophy', 28),
#  ('John Connolly', 'Theology', 28),
#  ('Robbie Nakatsu', 'Information Science', 28),
#  ('Chien Tseng', 'Mathematics', 28),
#  ('Amy Alward', 'Accounting', 28),
#  ('Matthew Pereira', 'Theological Studies', 28),
#  ('Kristi Lobitz', 'Music', 28),
#  ('Jonathan Rothchild', 'Theology', 28),
#  ('Roberto Cancio', 'Sociology', 28),
#  ('Trevor Zink', 'Business', 28),
#  ('Rafiql Noorani', 'Engineering', 28),
#  ('Anthony Kmetty', 'Business', 28),
#  ('Pat Oliver', 'Communication Studies', 27),
#  ('Chuck Rosenthal', 'English', 27),
#  ('Jose Badenes', 'Languages', 27),
#  ('Dave Smith', 'Mathematics', 27),
#  ('Richard Rohrer', 'Film', 27),
#  ('Aimee Koeplin', 'Philosophy', 27),
#  ('K. Dahlquist', 'Biology', 27),
#  ('Sun Hee Yoon', 'History', 27),
#  ('Joshua Hallam', 'Mathematics', 27),
#  ('Julian Saint Clair', 'Marketing', 27),
#  ('Wesley Kading', 'Business', 27),
#  ('Katerina Zacharia', 'Classics', 27),
#  ('Brian Moss', 'Fine Arts', 26),
#  ('William Pupa', 'Fine Arts', 26),
#  ('Michele Mega', 'Communication Studies', 26),
#  ('George Hess', 'Business', 26),
#  ('John Huddle', 'English', 26),
#  ('Derek Von Barandy', 'Philosophy', 26),
#  ('Jane Yamashiro', 'American Studies', 26),
#  ('Brandon Seto', 'History', 26),
#  ('Thomas Ramsey', 'Accounting', 26),
#  ('Arin Brahma', 'Computer Information Systems', 26),
#  ('Robin Miskolcze', 'English', 25),
#  ('Stephanie August', 'Computer Science', 25),
#  ('Thomas White', 'Business', 25),
#  ('Seth Thompson', 'Political Science', 25),
#  ('Kathy Yang', 'Languages', 25),
#  ('Thomas Rausch', 'Theology', 25),
#  ('Fr. Joe La Brie', 'Psychology', 25),
#  ('Herbert Medina', 'Mathematics', 25),
#  ('Ethan Adams', 'Classics', 25),
#  ('Josette Banks', 'Psychology', 25),
#  ('B.J. Johnson', 'Computer Science', 25),
#  ('Alessandro Varotto', 'Chemistry', 25),
#  ('Tracy Tiemeier', 'Theology', 25),
#  ('Gregori Viens', 'Film & Television', 24),
#  ('Marina Moevs', 'Fine Arts', 24),
#  ('Marc Lony', 'Languages', 24),
#  ('David Mathison', 'Management', 24),
#  ('Frank Daroca', 'Accounting', 24),
#  ('Matt Dillon', 'Classics', 24),
#  ('Michelle Hammers', 'Communication Studies', 24),
#  ('Rebecca Cantor', 'English', 24),
#  ('Shannon Nason', 'Philosophy', 24),
#  ('Rob Burchfield', 'Graphic Arts', 24),
#  ('Velitchka Kaltcheva', 'Marketing', 24),
#  ('Kevin Wetmore', 'Theater', 24),
#  ('Vivian Lezak', 'Mathematics', 24),
#  ('David Kovacs', 'Philosophy', 24),
#  ('Laura Poladian', 'Communication Studies', 24),
#  ('John P. Waggoner', 'Biology', 23),
#  ('Benjamin Bobo', 'Finance', 23),
#  ('Labina Ula', 'English', 23),
#  ('Michael Datcher', 'English', 23),
#  ('Kelley Falconer', 'Philosophy', 23),
#  ('Maria Valenzuela', 'American Studies', 23),
#  ('Jason Jenkins', 'English', 23),
#  ('Cassandra Veney', 'Political Science', 23),
#  ('Jose Tapia', 'Physics', 23),
#  ('Judy Siker', 'Theological Studies', 23),
#  ('Paul Harris', 'English', 23),
#  ('Andrew Dilts', 'Political Science', 23),
#  ('Christopher  Murphy', 'Philosophy', 23),
#  ('Eric Balmer', 'Philosophy', 23),
#  ("Michael O'Sullivan", 'Psychology', 22),
#  ('Christina Gold', 'History', 22),
#  ('Suzanne Larson', 'Mathematics', 22),
#  ('Katherine Harper', 'Art History', 22),
#  ('Jonas Mureika', 'Physics', 22),
#  ('John Beckwith', 'Business', 22),
#  ('Paige Edley', 'Communication Studies', 22),
#  ('Yevette Saavedra', 'Urban Studies', 22),
#  ('Margaret Trenchard-Smith', 'History', 22),
#  ('Guillo Della Rocca', 'Mathematics', 22),
#  ('Richard Fox', 'Political Science', 22),
#  ('Chela Willey', 'Psychology', 22),
#  ('Anthony Hui', 'Mathematics', 22),
#  ('Eddie Becton', 'American Studies', 22),
#  ('Saori Shiraki', 'Chemistry', 22),
#  ('Kevin McDonald', 'History', 22),
#  ('Claudia Sandoval', 'Political Science', 22),
#  ('Ed Gray', 'Business', 21),
#  ('Mary Ingham', 'Philosophy', 21),
#  ('Kate Lewis', 'Music', 21),
#  ('Cal Caswell', 'Business', 21),
#  ('Jose Saez', 'Engineering', 21),
#  ('Jane Brucker', 'Fine Arts', 21),
#  ('Matt Nelson', 'Communication Studies', 21),
#  ('Charlotte Radler', 'Religion', 21),
#  ('Matt Kursar', 'Mathematics', 21),
#  ('Richard Perle', 'Computer Information Systems', 21),
#  ('Susan Schaffer', 'Spanish', 21),
#  ('Jonghwa Lee', 'Communication Studies', 21),
#  ('Matthew Peterson', 'Political Science', 21),
#  ('David Berube', 'Physics', 21),
#  ('Stephanie Limoncelli', 'Sociology', 21),
#  ('Sona Gala', 'Business Law', 21),
#  ('Katharine Noon', 'Fine Arts', 20),
#  ('Chuck Erven', 'Theater', 20),
#  ('Elizabeth Murray', 'Philosophy', 20),
#  ('Jay Busse', 'Communication Studies', 20),
#  ('John Menaghan', 'English', 20),
#  ('Thomas Cappelli', 'Philosophy', 20),
#  ('Tim Burns', 'Philosophy', 20),
#  ('David Byrne', 'History', 20),
#  ('Barbara Lang', 'Ethnic Studies', 20),
#  ('Zbigniew Przasnyski', 'Business', 20),
#  ('Dominique Isner-Ball', 'French', 20),
#  ('James Bunker', 'Communication Studies', 20),
#  ('Paul Humphreys', 'Music', 20),
#  ('Joshua Kulmac Butler', 'English', 20),
#  ('Margarete Feinstein', 'Theological Studies', 20),
#  ('Richard Abrams', 'Psychology', 20),
#  ('Amanda Apgar', "Women's Studies", 20),
#  ('William Fulco', 'Anthropology', 19),
#  ('Alicia Partnoy', 'Languages', 19),
#  ('Eric Ladizinsky', 'Physics', 19),
#  ('Michael Genovese', 'Political Science', 19),
#  ('Mel Mendelson', 'Engineering', 19),
#  ('Shanna Kennedy-Quigley', 'Art History', 19),
#  ('Deanna Drew', 'English', 19),
#  ('Michael Petitti', 'English', 19),
#  ('Michelle Anderson', 'Psychology', 19),
#  ("Sean D''Evelyn", 'Economics', 19),
#  ('Sherine El Hag', 'Economics', 19),
#  ('Amanda Whidden', 'Communication Studies', 19),
#  ('Madhu Viswanathan', 'Marketing', 19),
#  ('Petra Liedke - Konow', 'German', 19),
#  ('Michael Vanbiezen', 'Mathematics', 18),
#  ('Peter Ring', 'Management', 18),
#  ('Rebecca Crawford', 'Chemistry', 18),
#  ('Larry Pate', 'Management', 18),
#  ('Victoria Newsom', 'Communication Studies', 18),
#  ('Jeremy Pal', 'Civil Engineering', 18),
#  ('Patrick Scott', 'Film & Television', 18),
#  ('Victor Carmona', 'Biology', 18),
#  ('Erica Steakley', 'English', 18),
#  ('Vicente Cassano', 'Biology', 18),
#  ('Amanda Herring', 'Art & Art History', 18),
#  ('Rachel Petrocelli', 'History', 18),
#  ('William Britt', 'Philosophy', 18),
#  ('Philip Reed-Butler', 'Theological Studies', 18),
#  ('Molly Youngkin', 'English', 18),
#  ('Michelle Miller', 'Economics', 18),
#  ('Jeff Phillips', 'Physics', 18),
#  ('Aimee Ross', 'English', 18),
#  ('Juan Ortiz', 'Mathematics', 18),
#  ('Jason Jarvis', 'Communication Studies', 18),
#  ('Barbara Marino', 'Engineering', 18),
#  ('Karl Snider', 'Music', 17),
#  ('John Dorsey', 'Science', 17),
#  ('David Killoran', 'English', 17),
#  ('Deena Gonzalez', 'Ethnic Studies', 17),
#  ('John Grever', 'History', 17),
#  ('John Stewart', 'Film', 17),
#  ('Nina Reich', 'Communication Studies', 17),
#  ('Jeff Gale', 'Business', 17),
#  ('Ron Marasco', 'Theater', 17),
#  ('Hiromi Kinjo', 'Languages', 17),
#  ('Eli Daughdrill', 'Film & Television', 17),
#  ('Christopher Chapple', 'Theology', 17),
#  ('Julia Lee', 'English', 17),
#  ('Sovathana Sokhom', 'Economics', 17),
#  ('Andrew Lac', 'Psychology', 17),
#  ('James Bany', 'Not Specified', 17),
#  ('Susie McDaniel', 'Communication Studies', 17),
#  ('Kerstin Fisk', 'Political Science', 17),
#  ('Maria Elena De Las Carreras', 'Film & Television', 17),
#  ('Chaya Crowder', 'Political Science', 17),
#  ('Nnogo Obiamiwe', 'Business Law', 17),
#  ('Gloria Shin', 'Film  Television', 17),
#  ('Karen Enriquez', 'Theology', 17),
#  ('Dean Scheibel', 'Communication Studies', 17),
#  ('Roy Houston', 'Science', 16),
#  ('Gary Kuleck', 'Science', 16),
#  ('Ross Bengel', 'Accounting', 16),
#  ('Carolyn Almos', 'Theater', 16),
#  ('Barbara Dyer', 'Music', 16),
#  ('Yvette Lapayese', 'Education', 16),
#  ('Marie Claire Costello', 'Theater', 16),
#  ('Jeffrey Siker', 'Religion', 16),
#  ('John Leaver', 'Art History', 16),
#  ('Steve Chrissanthos', 'History', 16),
#  ('Anton Smith', 'American Studies', 16),
#  ('Iliana Delarkin', 'Communication Studies', 16),
#  ("Jason D'Mello", 'Entrepreneurship', 16),
#  ('Bryan Pham', 'Theological Studies', 16),
#  ('Vanessa Diaz', 'Chicano Studies', 16),
#  ('Lawrence Wenner', 'Philosophy', 16),
#  ('Gerald Adler', 'Business', 16),
#  ('Cecilia Gonzalez-Andrieu', 'Theology', 16),
#  ('Christina Eubanks-Turner', 'Mathematics', 16),
#  ('Monique Mansour', 'Communication Studies', 16),
#  ('Marne Campbell', 'African-American Studies', 16),
#  ('Robert Senter', 'Chemistry', 16),
#  ('Stephen Heller', 'Chemistry', 16),
#  ('Sean Dempsey', 'History', 16),
#  ('Oscar Tovar', 'Philosophy', 16),
#  ('Charmaine Kaimikaua', 'Communication Studies', 16),
#  ('Negin Ghavami', 'Psychology', 16),
#  ('Vincent Coletta', 'Physics', 16),
#  ('Mark Saya', 'Music', 16),
#  ('Allison Noyes', 'Communication Studies', 16),
#  ('Rebecca Avalos', 'Communication Studies', 16),
#  ('Pamela Sklar', 'Management', 16),
#  ('Janie Streckenrider', 'Political Science', 15),
#  ('Mladen Milicevic', 'Film', 15),
#  ('Wilkie Au', 'Theology', 15),
#  ('Fatima Wu', 'Ethnic Studies', 15),
#  ('Jeffrey Davis', 'Film', 15),
#  ('Anja Leigh Russell', 'English', 15),
#  ('Tomo Hattori', 'English', 15),
#  ('John Parrish', 'Political Science', 15),
#  ('Cassie Cain', 'Mathematics', 15),
#  ('Michon Matthieson', 'Theological Studies', 15),
#  ('Mona Seymour', 'Urban Studies', 15),
#  ('Christiano Manfre', 'Economics', 15),
#  ('Christopher Finlay', 'Communication Studies', 15),
#  ('Ege Islekel', 'Philosophy', 15),
#  ('Mariano Bertucci', 'History', 15),
#  ('Natasha Miric', 'Sociology', 15),
#  ('Gene Park', 'Political Science', 15),
#  ('Sabine Huemer', 'Psychology', 15),
#  ('Tim Fitzgerald', 'Theater', 15),
#  ('Maria Vasquez', 'Biology', 15),
#  ('Thomas Laurent', 'Mathematics', 15),
#  ('Diane Meyer', 'Fine Arts', 15),
#  ('Lauren Cole', 'History', 15),
#  ("Derek D'Sa", 'Finance', 15),
#  ('Mobashera Hallam', 'Mathematics', 15),
#  ('Dustin Reece', 'Business', 15),
#  ('Eugene Brancolini', 'Communication Studies', 15),
#  ('Swarup Joshi', 'Economics', 15),
#  ('Kayoko Okada', 'Psychology', 15),
#  ('Sheila Forman', 'Psychology', 15),
#  ('Shirin Birjandi', 'Biology', 15),
#  ('Yasaman Ghasemi', 'Business', 15),
#  ('Jennifer Abe', 'Psychology', 14),
#  ('Reyna Valenzuela-Cummings', 'Communication Studies', 14),
#  ('Linda Bannister', 'English', 14),
#  ('Jackie Dewar', 'Mathematics', 14),
#  ('Mark Schwartz', 'Film', 14),
#  ('Hassan Hussain', 'History', 14),
#  ('Ayanna Yonemura', 'Urban Studies', 14),
#  ('Don Zirpola', 'Film', 14),
#  ('Gordon Firemark', 'Business Law', 14),
#  ('Joshua Blander', 'Philosophy', 14),
#  ('Dung Tran', 'Communication Studies', 14),
#  ('Kim Harris', 'Theological Studies', 14),
#  ('Xiaolong Wang', 'Economics', 14),
#  ('Joshua Spizman', 'Finance', 14),
#  ('Derrick Noyce', 'Music', 14),
#  ('Han Dai-Yu', 'Art & Art History', 14),
#  ('Joseph Hattendorf', 'Accounting', 14),
#  ('Leena Pendharker', 'Film', 14),
#  ('Maxellende Ezin', 'Biology', 14),
#  ('Tony Kmetty', 'Business', 14),
#  ('Catie Mihalopoulos', 'Classics', 13),
#  ('Philip Dorin', 'Computer Science', 13),
#  ('Bruno Rota', 'Languages', 13),
#  ('William Trott', 'Engineering', 13),
#  ('Sandy Kirkner', 'Psychology', 13),
#  ('Garland Kirkpatrick', 'Graphic Arts', 13),
#  ('Renee Florsheim', 'Marketing', 13),
#  ('Martha Masters', 'Music', 13),
#  ("Roberto Dell'Oro", 'Theological Studies', 13),
#  ('Nenad (Neno) Pervan', 'Theater', 13),
#  ('Marc Reeves', 'Theology', 13),
#  ('Cythina Bond', 'Theology', 13),
#  ('Timothy Helton', 'Theology', 13),
#  ('Angela Gallegos', 'Mathematics', 13),
#  ('Courtney Pina', 'English', 13),
#  ('Tyler Ferreira', 'Art & Art History', 13),
#  ('Rachel Fox', 'Theological Studies', 13),
#  ('Sohvi Heaton', 'Business', 13),
#  ('Mark Bernier', 'Philosophy', 13),
#  ('Dermott Walsh', 'Theology', 13),
#  ('Terry Lenihan', 'Fine Arts', 13),
#  ('Mitchell Hamilton', 'Marketing', 13),
#  ('Arthur Gross-Schaefer', 'Business Law', 13),
#  ('Diana Santacrose', 'Psychology', 13),
#  ('Matthew Siniawski', 'Mechanical Engineering', 13),
#  ('Eliza Rodriguez Y Gibson', 'Chicano Studies', 13),
#  ('Richard Cook', 'Mathematics', 12),
#  ('Michael Barclay', 'Theology', 12),
#  ('James Holmes', 'Theater', 12),
#  ('Rachelle Katz', 'Business Administration', 12),
#  ('William Semos', 'Business Administration', 12),
#  ('Maria Nazarian', 'Psychology', 12),
#  ('Lawrence Kalbers', 'Accounting', 12),
#  ('Deborah Harris', 'English', 12),
#  ('Seth Kim', 'Economics', 12),
#  ('Craig Rich', 'Communication Studies', 12),
#  ('Julie McGene', 'Sociology', 12),
#  ('Adilifu Nama', 'African-American Studies', 12),
#  ('Andrew Devereux', 'History', 12),
#  ('Annemarie Perez', 'English', 12),
#  ('Amina  Humphrey', 'American Studies', 12),
#  ('Alma Flores', 'Chicano Studies', 12),
#  ('Mugdha Yeolekar', 'Theology', 12),
#  ('Dave Harvilicz', 'Management', 12),
#  ('Shan Wang', 'Accounting', 12),
#  ('Michael Manoogian', 'Engineering', 12),
#  ('Myla Bui-Nguyen', 'Marketing', 12),
#  ('John Bakas', 'Theology', 12),
#  ('Kristen Smiarowski', 'Fine Arts', 12),
#  ('Virginia Saya', 'Music', 12),
#  ('Carolyn Viviano', 'Biology', 12),
#  ('Sean Winkler', 'Philosophy', 12),
#  ('Alexander Zambrano', 'Philosophy', 12),
#  ('William McClain', 'Communication Studies', 12),
#  ('Philip Chmielewski', 'Engineering', 12),
#  ('Lisa Harris', 'Psychology', 11),
#  ('Luis Proenca', 'Film', 11),
#  ('John Emerling', 'Art History', 11),
#  ('Michael Mulvihill', 'Engineering', 11),
#  ('Leland Swenson', 'Psychology', 11),
#  ('Wojciech Kocyan', 'Music', 11),
#  ('Mario Congreve', 'Film', 11),
#  ('Bob Robinson', 'Philosophy', 11),
#  ('Jeff Thies', 'Business', 11),
#  ('Chris Haddy', 'Education', 11),
#  ('Paul Desena', 'Education', 11),
#  ('Joseph Puterbaugh', 'English', 11),
#  ('Francisco Ramos', 'Education', 11),
#  ('Nicole Woods', 'Art History', 11),
#  ('Linda Hasunuma', 'Political Science', 11),
#  ('Susan Feldman', 'English', 11),
#  ('Daniel Bonilla', 'Natural Sciences', 11),
#  ('Cecilia Martinez-Gil', 'English', 11),
#  ('John Dionisio', 'Computer Science', 11),
#  ('Ulli Ryder', 'American Studies', 11),
#  ('Prachi Jain', 'Economics', 11),
#  ('Erin Kaplan', 'Economics', 11),
#  ('Ashleigh Campi', 'Political Science', 11),
#  ('Eugenio Volpe', 'English', 11),
#  ('Catherine Peters', 'Philosophy', 11),
#  ('Emma Davis', 'Economics', 11),
#  ('Roy Fisher', 'Theological Studies', 11),
#  ('Doris Namala', 'History', 10),
#  ('Laurel Ollstein', 'Theater', 10),
#  ('Pamela Goldblum', 'Fine Arts', 10),
#  ('Dan Weingarten', 'Theater', 10),
#  ('Dana Reemes', 'Archaeology', 10),
#  ('Mark Gordon', 'Sociology', 10),
#  ('Deke Simon', 'Film & Television', 10),
#  ('Shawki El-Zatmah', 'History', 10),
#  ('Thuy Vo Dang', 'American Studies', 10),
#  ('David Lerner', 'Film & Television', 10),
#  ('Chris Zepeda-Millian', 'Political Science', 10),
#  ('Alissa Zito', 'Communication Studies', 10),
#  ('Nari Choi', 'Mathematics', 10),
#  ('Jennifer Moorman', "Women's Studies", 10),
#  ('Kathryn Mouzakis', 'Chemistry', 10),
#  ('Gil Klein', 'Theological Studies', 10),
#  ('Ann LE', 'Studio Art', 10),
#  ('Bernadette Musetti', 'Education', 10),
#  ('Brandon Shamim', 'Business', 10),
#  ('Edgar Rothermich', 'Audio Production', 10),
#  ('Frederick Ayeroff', 'Film & Television', 10),
#  ('Dana Resnick', 'Theater', 10),
#  ('Brian Reedy', 'Theology', 10),
#  ('Zahra Alavi', 'Physics', 10),
#  ('Yanjie Wang', 'Asian Pacific American Studies', 10),
#  ('Ernesto Colin', 'Education', 9),
#  ('Caprice Walker', 'Theater', 9),
#  ('Eric Hall', 'Philosophy', 9),
#  ('John Hartmann', 'Media & Performing Arts', 9),
#  ('Darryl Graver', 'Business Law', 9),
#  ('David Ramirez', 'Health Sciences', 9),
#  ('Rachel Adams', 'Environmental Science', 9),
#  ('Sharon Madden', 'Theater', 9),
#  ('Laurence Dumortier', 'English', 9),
#  ("Thomas D'Amico", 'Philosophy', 9),
#  ('Vernita Burrell', 'English', 9),
#  ('George Saraf', 'Economics', 9),
#  ('Katherine Rhodes', 'English', 9),
#  ('Courtney Spikes', 'History', 9),
#  ('Rosalie Siemon', 'Philosophy', 9),
#  ('David Sheridan', 'History', 9),
#  ('Margaret Gower', 'Theological Studies', 9),
#  ('Nicholas Centino', 'Chicano Studies', 9),
#  ('Adriana Sanford', 'Business Law', 9),
#  ('Juan Garcia Torres', 'Philosophy', 9),
#  ('Zining Li', 'Accounting', 9),
#  ('Jennifer Jones', 'Political Science', 9),
#  ('Angelique Young', 'English', 9),
#  ('Dennis Kwong', 'Film', 9),
#  ('Lei Huang', 'Engineering', 9),
#  ('Oskar Toruno', 'Film', 9),
#  ('Alexandra Sturm', 'Psychology', 9),
#  ('Mary Kuryla', 'Film', 9),
#  ('Mark Diamond', 'Theological Studies', 9),
#  ('Kristen Covino', 'Biology', 9),
#  ('Gabriele Varieschi', 'Physics', 9),
#  ('Gregory Lontok', 'Computer Information Systems', 9),
#  ('Alexander Glosenberg', 'Entrepreneurship', 9),
#  ('Fulya Ersoy', 'Economics', 9),
#  ('Nirinjan Khalsa', 'Theological Studies', 9),
#  ('Tyler Harlan', 'Urban Studies', 9),
#  ('Maureen Fitzsimmons', 'Liberal Studies', 9),
#  ('Scott Roniger', 'Philosophy', 9),
#  ('Soumya Mukherjee', 'Business', 9),
#  ('Si Jun Wang', 'Marketing', 9),
#  ('Bob Ackley', 'Fine Arts', 8),
#  ('Erica Byrne', 'Film', 8),
#  ('Sylvia Morales', 'Film', 8),
#  ('Phyllis Green', 'Fine Arts', 8),
#  ('Raymond Greene', 'Film', 8),
#  ('Kambiz Moghaddam', 'Dance', 8),
#  ('Lee Cenquizca', 'Natural Sciences', 8),
#  ('Judith Royer', 'Theater', 8),
#  ('Richard Freiman', 'Film', 8),
#  ('L Boland', 'Engineering', 8),
#  ('Thomas Muller', 'Fine Arts', 8),
#  ('Gabe Griffith', 'Philosophy', 8),
#  ('Tekla Kostek', 'Dance', 8),
#  ('Andrea O. Fuller', 'Theater', 8),
#  ('Shawki El Zatmah', 'History', 8),
#  ('Joanna Burgarino', 'English', 8),
#  ('Maura Captain', 'Education', 8),
#  ('Nara Chea', 'Economics', 8),
#  ('Arif Karim', 'Chemistry', 8),
#  ('Jon Mochizuki', 'American Studies', 8),
#  ('Alexandra Neel', 'English', 8),
#  ('Robert Cross', 'History', 8),
#  ('Terri Anderson', 'Sociology', 8),
#  ('Yvette Mylett', 'English', 8),
#  ('Hillary Hintzen', 'English', 8),
#  ('Matthew Werber', 'Physics', 8),
#  ('Evelyn McDonnell', 'English', 8),
#  ('Nora Zepeda', 'Spanish', 8),
#  ('Norma Bowles', 'Theater', 8),
#  ('Susan Abraham', 'Theology', 8),
#  ('Rosalie  Lochner ', "Women's Studies", 8),
#  ('Eric Meyer', 'Theological Studies', 8),
#  ('Kristina Markman', 'History', 8),
#  ('Shaun Anderson', 'Communication Studies', 8),
#  ('Serhiy Hovorun', 'Theological Studies', 8),
#  ('Kuo-Sheng Ma', 'Electrical Engineering', 8),
#  ('Daisy Cheng', 'Mathematics', 8),
#  ('Danielle Gibson', 'English', 8),
#  ('Emily Jarvis', 'Chemistry', 8),
#  ('Dmitry Kmelnitsky', 'Art', 8),
#  ('Kenneth Provencher', 'Film & Television', 8),
#  ('Sariolghalam Mahmood', 'Political Science', 8),
#  ('Paul Rude', 'Engineering', 7),
#  ('Jennie Spencer Green', 'Education', 7),
#  ('Brant Kline', 'Business Administration', 7),
#  ('Elaine Walker', 'Communication Studies', 7),
#  ('Forouzan Faridian', 'Physics', 7),
#  ('Saeri Cho', 'Art', 7),
#  ('Dalia Muller', 'History', 7),
#  ('Pepper Glass', 'Sociology', 7),
#  ('John Glavan', 'Communication Studies', 7),
#  ('James Kintz', 'Philosophy', 7),
#  ('Julie Suh', 'Accounting', 7),
#  ('Angela James', 'African-American Studies', 7),
#  ('Luke Woodruff', 'Theater', 7),
#  ('Monica Marquez', 'Spanish', 7),
#  ('Paul Chitlik', 'Film & Television', 7),
#  ('Scott Heinzerling', 'Dance', 7),
#  ('Feryal Cherif', 'Political Science', 7),
#  ('Laura Massa', 'Psychology', 7),
#  ('Timothy Hogue', 'Theological Studies', 7),
#  ('Sunai Kim', 'Civil Engineering', 7),
#  ('Michael Daley', 'Film & Television', 7),
#  ('Daniel Jacobs', 'Business', 7),
#  ('Robert Kritzler', 'Accounting', 7),
#  ('David Garber', 'Film amp Television', 7),
#  ('Joshua Mason', 'Philosophy', 7),
#  ('Daniel Freedland', 'Communication Studies', 7),
#  ('Zhen Tang', 'Marketing', 7),
#  ('Sharon Mooney', 'Film  Television', 7),
#  ('Douglas Burton-Christie', 'Theological Studies', 7),
#  ('Mark Anderson', 'History', 7),
#  ('Tyler De Groot', 'Accounting', 7),
#  ('Micah Officer', 'Finance', 7),
#  ('Lisa Daggett', 'Business', 7),
#  ('Cory Evans', 'Biology', 7),
#  ('Gabriele Magni', 'Political Science', 7),
#  ('Lauren Guerra', 'Theology', 7),
#  ('Megan Gallipeau', 'Mathematics', 7),
#  ('Francisco Valle', 'Business', 7),
#  ('Luciano Manfredi Console', 'Mathematics', 7),
#  ('Bryan Wisch', 'English', 7),
#  ('Lucy Cook', 'Computer Information Systems', 7),
#  ('Debra Rosser', 'Science', 6),
#  ('Nazmul Ula', 'Engineering', 6),
#  ('Mike Daniels', 'Journalism', 6),
#  ('Katharine Clemmer', 'Education', 6),
#  ('Natalie Rivetti-Oritiz', 'Mathematics', 6),
#  ('Reyna V. Cummings', 'Communication Studies', 6),
#  ('Thomas McDermott', 'Music', 6),
#  ('Jay Douglas', 'Film', 6),
#  ('Eugenia Sileoni', 'Spanish', 6),
#  ('Barbara Christie', 'Natural Sciences', 6),
#  ('Grant Garinger', 'Theater', 6),
#  ('Amy Willard', 'Communication Studies', 6),
#  ('Jongmae Park', 'Theology', 6),
#  ('Lizy Moromisato', 'Languages', 6),
#  ('Emek Kose Can', 'Mathematics', 6),
#  ('Linda Yellin', 'Sociology', 6),
#  ('Mia McIver', 'English', 6),
#  ('Heather Hoffman', 'English', 6),
#  ('Donald Dilliplane', 'English', 6),
#  ('Zenadia Ramos', 'Mathematics', 6),
#  ('Justin Campbell', 'English', 6),
#  ('Hafedh Herichi', 'Mathematics', 6),
#  ('Teresa  Munoz', 'Art  Art History', 6),
#  ('Paul Monson', 'Theology', 6),
#  ('Sarah Strand', 'Health Sciences', 6),
#  ('Stanley Lewis', 'Business', 6),
#  ('Kevin Del Principe', 'Film  Television', 6),
#  ('Le Gui', 'Mathematics', 6),
#  ('Benham Ziaei', 'Mathematics', 6),
#  ('Lisa Herzog', 'Business Law', 6),
#  ('Karen Papazian', 'Business', 6),
#  ('Ignacio Higareda', 'Education', 6),
#  ('Mehrdad Sharbaf', 'Computer Information Systems', 6),
#  ('Rich Martini', 'Film amp Television', 6),
#  ('Charles Peterson', 'Art & Art History', 6),
#  ('Eddie Malone', 'English', 6),
#  ('Alex Jacoby', 'History', 6),
#  ('Vanessa Newell', 'Film & Television', 6),
#  ('Jenny Ferguson', 'English', 6),
#  ('Shanna Hughes', 'Dance', 6),
#  ('Glenn Gebhart', 'Film', 6),
#  ('Joshua Beckett', 'Theology', 6),
#  ('Marcela Garcia-Romero', 'Philosophy', 6),
#  ('Lawrence Lacey', 'Theater', 6),
#  ('Hossein Asghari', 'Computer Science', 6),
#  ('Steve Duncan', 'Film', 5),
#  ('Judy Scalin', 'Dance', 5),
#  ('Wenshu Lee', 'Communication Studies', 5),
#  ('Christine Cain', 'Education', 5),
#  ('Karen Huchting', 'Education', 5),
#  ('Jeffrey Lindstrom', 'Economics', 5),
#  ('Nadine McGuinness', 'Theological Studies', 5),
#  ('Ruth Lane', 'English', 5),
#  ('Ross Mann', 'English', 5),
#  ('Jennifer Hsieh', 'Biology', 5),
#  ('Misha Tadd', 'Theological Studies', 5),
#  ('Erika Perez', 'American Studies', 5),
#  ('Elaine Goodfriend', 'Theology', 5),
#  ('Ivy Cargile', 'Political Science', 5),
#  ('Paul Reinsch', 'Film & Television', 5),
#  ('Laura Rectenwald', 'English', 5),
#  ('Steve Sherwood', 'Sociology', 5),
#  ('Jesse Mills', 'Political Science', 5),
#  ('Yan Yan Yang', 'Economics', 5),
#  ('Lucy Kilp', 'Psychology', 5),
#  ('James Kilcup', 'Communication Studies', 5),
#  ('Marick Sinay', 'Mathematics', 5),
#  ('Katie King', 'English', 5),
#  ('Nicholas Thaler', 'Psychology', 5),
#  ('Leah Smith', 'Film  Television', 5),
#  ('Elizabeth Rahilly', 'Sociology', 5),
#  ('David Garden', 'Film', 5),
#  ('David Sapp', 'Education', 5),
#  ('Jennifer Williams', 'African-American Studies', 5),
#  ('Alissa Volosin', 'Computer Science', 5),
#  ('Nigel Billings', 'Engineering', 5),
#  ('Laura Bloomfield', 'Engineering', 5),
#  ('Lan Ngo', 'Asian Pacific American Studies', 5),
#  ('Jacqueline McSweeney', 'Environmental Science', 5),
#  ('Kalliopi Kefalas', 'Greek', 5),
#  ('Nicholas Virginio', 'Marketing', 5),
#  ('Luis Sanchez Lopez', 'Chicano Studies', 5),
#  ('Steven Nygaard', 'Education', 5),
#  ('Patricia Oliver', 'Communication Studies', 5),
#  ('Sarah Emanuel', 'Theological Studies', 5),
#  ('Joseph Weber', 'Civil Engineering', 5),
#  ('Townsend Scholz', 'English', 5),
#  ('Grace Kao', 'Theology', 5),
#  ('Nathan Sessoms', 'Sociology', 5),
#  ('Daphne Sicre', 'Theater', 5),
#  ('Shirin Mollah', 'Economics', 5),
#  ('Devon Golaszewski', 'History', 5),
#  ('Jill Nunes-Jensen', 'Dance', 5),
#  ('Kimberly Icreverzi', 'Film', 5),
#  ('Demetrios Liappas', 'Languages', 4),
#  ('Michelle Lum', 'Biology', 4),
#  ('Kwaku Person-Lynn', 'Urban Studies', 4),
#  ('Graham Beckel', 'Theater', 4),
#  ('Tammy Pao', 'Computer Science', 4),
#  ('Michael Stock', 'English', 4),
#  ('Anna Sarrano', 'Education', 4),
#  ('Robert Stephan', 'History', 4),
#  ('Thomas Whaling', 'Philosophy', 4),
#  ('Lee Feldman', 'Business Law', 4),
#  ('Elizabeth Dively-Lauro', 'Theological Studies', 4),
#  ('Suzie Abajian', 'Mathematics', 4),
#  ('John Strickland', 'History', 4),
#  ('Henry Nguyen', 'Theological Studies', 4),
#  ('Kevin Griffin', 'Biology', 4),
#  ('Nicholas Denysenko', 'Theology', 4),
#  ('Andrew Rohm', 'Business', 4),
#  ('Casey Shoop', 'English', 4),
#  ('Elizabeth Barr', 'English', 4),
#  ('Thomas Ward', 'Philosophy', 4),
#  ('Hannah Dow', 'English', 4),
#  ('Thomas Buckley', 'History', 4),
#  ('Selene Zander', 'Spanish', 4),
#  ('Isaac Speer', 'Sociology', 4),
#  ('Mikael Kreuzriegler', 'Film & Television', 4),
#  ('Stacy Sinclair', 'Education', 4),
#  ('Veronika Harder', 'Economics', 4),
#  ('Christopher Chien', 'English', 4),
#  ('Ali Dehghan', 'Marketing', 4),
#  ('Marilyn McLaughlin', 'Dance', 4),
#  ('Alexa Bolton', 'English', 4),
#  ('Sergio Gaudio', 'Physics', 4),
#  ('Bryan Miller', 'Communication Studies', 4),
#  ('Benjamin Finck', 'Chemistry', 4),
#  ('Liza Taylor', 'Political Science', 4),
#  ('Mark Lucas', 'Finance', 4),
#  ('Mahmoud Salari', 'Economics', 4),
#  ('Shane Andrews', 'Communication Studies', 4),
#  ('Stefan Bradley', 'African-American Studies', 4),
#  ('Dallas King', 'Film & Television', 4),
#  ('Margaret Oberman', 'Film & Television', 4),
#  ('Michael Moore', 'Accounting', 4),
#  ('Clark Zhu', 'Film', 4),
#  ('Cody Brown', 'Political Science', 4),
#  ('Taryn Vanderhoop', 'Dance', 4),
#  ('Konstantin Platanov', 'Economics', 4),
#  ('Marc Pitre', 'Film & Television', 4),
#  ('Dan Watanabe', 'Film amp Television', 4),
#  ('Anthony Menendez', 'Accounting', 4),
#  ('Mary McCusker', 'Theater', 4),
#  ('Catharine Christof', 'Theater', 4),
#  ('Matthew Dewey', 'Communication Studies', 4),
#  ('Lauren Wilson', 'Film & Television', 4),
#  ('Pauline Ebert', 'German', 4),
#  ('Brendan Smith', 'Mechanical Engineering', 4),
#  ('Christopher SooHoo', 'Art & Art History', 4),
#  ('Elizabeth Dewey', 'Film & Television', 4),
#  ('James Sadler', 'History', 4),
#  ('Mitch Rufca', 'Business', 4),
#  ('Thomas Ford', 'Environmental Science', 4),
#  ('Frank Sheppard', 'Theater', 4),
#  ('Laura Smyth', 'Dance', 4),
#  ('Elizabeth Quinn', 'Film & Television', 4),
#  ('Kimberly Moekle', 'English', 4),
#  ('Sara Simpson', 'Psychology', 4),
#  ('Dee Filecia', 'Political Science', 4),
#  ('Jessica Martinez-Tebbel', "Women's Studies", 4),
#  ('Tyler Edmiston', 'Computer Science', 4),
#  ('Simon Aihiokhai', 'Theological Studies', 4),
#  ('Robert Caro', 'English', 3),
#  ('Laurie Beyer', 'Education', 3),
#  ('Peter Soto', 'Film', 3),
#  ('Kathy Baur', 'Animation', 3),
#  ('Maureen Schaukowitch', 'Education', 3),
#  ('Ken Simmonds', 'Accounting', 3),
#  ('Bill Sanders', 'Marketing', 3),
#  ('Carolyn Brooks', 'Education', 3),
#  ('Thomas Mueller', 'Art & Art History', 3),
#  ('Christine Nangle', 'Communication Studies', 3),
#  ('Alecia Molezion', 'Communication Studies', 3),
#  ('Joshua Hayes', 'Philosophy', 3),
#  ('Gregory Canillas', 'Psychology', 3),
#  ('Sonja Kemp', 'Business', 3),
#  ('Victor Polanco', 'American Studies', 3),
#  ('Jane Yamashiro', 'Sociology', 3),
#  ('Laura Diaz', 'English', 3),
#  ('Nicole Morris', 'English', 3),
#  ('Susie Woo', 'American Studies', 3),
#  ('Don Schroeder', 'Film & Television', 3),
#  ('Joseph Pak', 'Philosophy', 3),
#  ('Rozy Vig', 'Mathematics', 3),
#  ('Candice Nicolas', 'French', 3),
#  ('Lucia Singer', 'Communication Studies', 3),
#  ('Janna Goebel', 'English', 3),
#  ('Julie Cohen', 'History', 3),
#  ('Gabrielle Shulman', 'English', 3),
#  ('Paul Keller', 'Theological Studies', 3),
#  ('Eric Saulnier', 'History', 3),
#  ('Nicole Valenzuela', 'Biology', 3),
#  ('Chiara Sulprizio', 'Archaeology', 3),
#  ('Cody Packard', 'Psychology', 3),
#  ('Arthur Kiureghian', 'Business Law', 3),
#  ('Benjamin Yeo', 'Computer Information Systems', 3),
#  ('Judith Williams', 'Biology', 3),
#  ('Elizabeth Quiros-Loe', 'Theological Studies', 3),
#  ('Kofi Yankey', 'Economics', 3),
#  ('Michael Levi', 'Health Sciences', 3),
#  ('Robert Burgos', 'Film & Television', 3),
#  ('Tim Huffman', 'Communication Studies', 3),
#  ('Amy Nielsen', 'Chemistry', 3),
#  ('Eric Taylor', 'Communication Studies', 3),
#  ('Julia Gosart', 'American Studies', 3),
#  ('Rosalio Cedillo', 'Sociology', 3),
#  ('Shane Acker', 'Film', 3),
#  ('Deborah Novak', 'Health Sciences', 3),
#  ('Taylor Holbrook', 'Liberal Studies', 3),
#  ('Amanda Beer', 'Psychology', 3),
#  ('Ian McDonald', 'English', 3),
#  ('Alice Taylor', 'Political Science', 3),
#  ('Helen Kim', 'Education', 3),
#  ('David Pinzur', 'Sociology', 3),
#  ('Daniel Manchala', 'Computer Science', 3),
#  ('John Becker', 'Theology', 3),
#  ('Ai Li', 'Philosophy', 3),
#  ('Alex Wong', 'Computer Science', 3),
#  ('David Idol', 'Greek', 3),
#  ('Matthew Dillon', 'Classics', 3),
#  ('Samuel Beckelhymer', 'Greek', 3),
#  ('Ronnie Clark', 'Theater', 3),
#  ('Aaron Smith', 'Music', 3),
#  ('June Duarte', 'Dance', 3),
#  ('Sami Siegelbaum', 'Art  Art History', 3),
#  ('Stacey Cabaj', 'Theater', 3),
#  ('Sarah Mitchell', 'Chemistry', 3),
#  ('Mavis Rode', 'Dance', 3),
#  ('Joseph Hellige', 'Psychology', 3),
#  ('Yves Vendes', 'Philosophy', 3),
#  ('Brenda Nicolas', 'Chicano Studies', 3),
#  ('Corinna Laughlin', 'Communication Studies', 3),
#  ('Andres Matlock', 'Classics', 3),
#  ("Walpa D'Mark", 'Studio Art', 3),
#  ('Gursel Aliyev', 'Economics', 3),
#  ('Miranda Banks', 'Film & Television', 3),
#  ('Leena Hingnikar', 'Business Law', 3),
#  ('Mandy Korpusik', 'Computer Science', 3),
#  ('Amber Bratcher-Covino', 'Biology', 3),
#  ('Abran Padilla', 'Business', 3),
#  ('Ian Moore', 'Philosophy', 3),
#  ('Ingrid Greene', 'Management', 3),
#  ('Rosanna Lu', 'Theology', 3),
#  ('Charles Erven', 'Theater', 3),
#  ('Au Vo', 'Computer Information Systems', 3),
#  ('Gregory Ruzzin', 'Film amp Television', 3),
#  ('Klaus Shipman', 'Film & Television', 3),
#  ('T.J. Harper', 'Music', 3),
#  ('Peter Ferguson', 'Electrical Engineering', 3),
#  ('Sandibel Borges', "Women's Studies", 3),
#  ('Rochelle Webb', 'Entrepreneurship', 3),
#  ('Barbara Busse', 'Communication Studies', 2),
#  ('Debbie Davis', 'Education', 2),
#  ('Slobodan Sijan', 'Film & Television', 2),
#  ('Michael Domaguing', 'Marketing', 2),
#  ('Keith Ellison', 'Natural Sciences', 2),
#  ('Teresa Romero', 'History', 2),
#  ('Susan Abelein', 'Education', 2),
#  ('Dan Kennedy', 'Classics', 2),
#  ('Phil Pannell', 'Education', 2),
#  ('Karen Hawkins', 'Education', 2),
#  ('Phil Wander', 'Communication Studies', 2),
#  ('Simon Karmarker', 'Management', 2),
#  ('Helen Alatorre', 'Education', 2),
#  ('Diane Fiello', 'Education', 2),
#  ('Warren Wright', 'Mathematics', 2),
#  ('Maral Reyes', 'Education', 2),
#  ('Tania Fleischer', 'Music', 2),
#  ('Steve Michaud', 'Business', 2),
#  ('Emily Scherberth', 'Communication Studies', 2),
#  ('James Carroll', 'Management', 2),
#  ('David Matheson', 'Business', 2),
#  ('Lynell George', 'English', 2),
#  ('Ramona Wright', 'Communication Studies', 2),
#  ('Kathleen Foy', 'Philosophy', 2),
#  ('Patrick Doyle', 'Psychology', 2),
#  ('Lorne Platt', 'Urban Studies', 2),
#  ('James Roe', 'Chemistry', 2),
#  ('Thomas Leach', 'Film & Television', 2),
#  ('Dorian Llwelyn', 'Theological Studies', 2),
#  ('Tom Sharp', 'Education', 2),
#  ('Monica Osborne', 'English', 2),
#  ('Catherine Skibo', 'Chemistry', 2),
#  ('Corinna Silva Da Veiga Jardim', 'German', 2),
#  ('Kaci Cooper', 'English', 2),
#  ('Milka Broukhim', 'Studio Art', 2),
#  ('Junyi Liu', 'Asian Pacific American Studies', 2),
#  ('Albertus Laksana', 'Theological Studies', 2),
#  ('Charles Tang', 'Engineering', 2),
#  ('Xandra Kayden', 'Political Science', 2),
#  ('Katelyn Quinley', 'English', 2),
#  ('Dudley Gray', 'Communication Studies', 2),
#  ('Janice Littlejohn', 'English', 2),
#  ('Sheron Mark', 'Environmental Science', 2),
#  ('Sean Hooks', 'English', 2),
#  ('Wesley Dowd', 'Biology', 2),
#  ('Corey Eccles', 'Audio Production', 2),
#  ('Christopher Cobb', 'Engineering', 2),
#  ('Morgan Land', 'Film  Television', 2),
#  ('Timothy Shea', 'Art  Art History', 2),
#  ('Amy Shevitz', 'Theological Studies', 2),
#  ('Robin Johnson', 'Art  Art History', 2),
#  ('Haley Young', 'Computer Science', 2),
#  ('Yvette Saavedra', 'Chicano Studies', 2),
#  ('Raynee Gutting', 'Political Science', 2),
#  ('Donald Kendall', 'Civil Engineering', 2),
#  ('Lisa Upshaw', 'Health Sciences', 2),
#  ...]

# %% [markdown]
# It looks like the Megan Granich has the most reviews in Mathematics. I am guessing she most likely teaches a large lower division class. I am also noticing that there are a lot of BCLA and Seaver teachers in the top 10 highest ratings. This may be due to how many students are attending those colleges. Another reason may be due to how they teach. I would think a controversial teacher would garner more reviews than a teacher who did not stand out.

# %% [markdown]
# I want to see if there are any professors who have no ratings, but are on Rate my Professor

# %%
# %%sql
# SELECT
#     COUNT(Instructor) AS CountInstructors
# FROM rmp_ratings rr
# WHERE CountRatings = 0;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1 rows affected.
# [(169,)]

# %% [markdown]
# That is surprising. If there are 169 professor who have no rating at all, why are they on RMP? My best theory is that the people who gave their reviews ultimately deleted it which resulted in a professor with no reviews. It might be worthwile to see how professors are generated in Rate my Professor. Are they created when someone inputs their first review, or do they acquire the data elsewhere?

# %% [markdown]
# ## Primary Question

# %% [markdown]
# Based off my descriptive analytics, I am worried that the professors who are on Prowl are not all on Rate my Professor. The question I would like to answer is: How many professors are in Prowl and have a rating in Rate my Professor? To accomplish this, I would like to start off by creating a view that combines both all of the teachers in Prowl with all of the teachers in Rate My Professor. I also want to include any rating information
#
# SQL Features Used: VIEW, JOIN

# %%
# %%sql
# CREATE OR REPLACE VIEW prowl_rmp AS
# (
#     SELECT
#         t.Instructor AS ProwlInstructor,
#         rr.Instructor AS RMPInstructor,
#         rr.Rating,
#         rr.Difficulty
#     FROM teachers t
#     LEFT JOIN rmp_ratings rr
#         ON t.InstructorID = rr.InstructorID
#     UNION
#     SELECT
#         t.Instructor AS ProwlInstructor,
#         rr.Instructor AS RMPInstructor,
#         rr.Rating,
#         rr.Difficulty
#     FROM teachers t
#     RIGHT JOIN rmp_ratings rr
#         ON t.InstructorID = rr.InstructorID
# );
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 0 rows affected.
# []

# %% [markdown]
# Using this view, my first query I am interested in looking into is to see how many professors are in RMP, how many are in Prowl, and how many are in Prowl that have a rating. I would also like to include the average rating and difficulty.
#
# SQL Features used: Subquery

# %%
# %%sql
# SELECT
#     COUNT(RMPInstructor) AS CountRMPInstructors,
#     COUNT(ProwlInstructor) AS CountProwlInstructors,
#     (
#         SELECT
#             SUM(CASE WHEN ProwlInstructor = RMPInstructor THEN 1 ELSE 0 END) AS ProwlInRMP
#         FROM prowl_rmp
#     ) AS CountProwlInRMP,
#     ROUND(AVG(Rating), 2) AS AvgRating,
#     ROUND(AVG(Difficulty), 2) AS AvgDifficulty
# FROM prowl_rmp;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 1 rows affected.
# [(1396, 771, Decimal('368'), 3.33, 2.52)]

# %% [markdown]
# This surprises me. Out of the 771 professors teaching for fall semester, it looks like Rate my Professor only acknowledges 368 of those professors. I would recommend that Rate My Professor looks into the collection of the teacher data. A suggestion I have is to utilize student ambassadors that have access to these teacher databases. If Rate My Professor has access to each of these databases, they can continuously update teacher data. Each year students will be able to search for their professors and always find them. Unfortunately, right now, only about half of the teachers are available for students to research. I think it might be useful to look into what teachers on Prowl have ratings. Two questions that arise from this data is what prowl specific teachers are getting the most reviews? Also, are there specific departments that gain more reviews than others?

# %% [markdown]
# ## Secondary Questions

# %% [markdown]
# Show Every teacher who is in Prowl that has a rating. For each teacher, also show their subject, the amount of total ratings they have. Rank the amount of ratings by department, I suspect that there may be specific departments with higher ratings than others.
#
# To follow this up, I want to look at the teachers who are on Prowl and also Rate My Professor. I will rank each professor by the amount of ratings they have on Prowl and partition it by department. The question I would like to answer from this is: What teachers in Prowl garner the highest count of rankings by each department?
#
# SQL Features Used: Group By, Window Function

# %%
# %%sql
# SELECT
#     t.Instructor,
#     c.Subject,
#     COUNT(rr.CountRatings) AS CountRatings,
#     RANK() OVER (
#         PARTITION BY c.Subject
#         ORDER BY COUNT(rr.CountRatings) DESC) AS CountRatingsRanked
#     FROM rmp_ratings rr
#     RIGHT JOIN teachers t
#         ON rr.InstructorID = t.InstructorID
#     RIGHT JOIN classes c
#         ON t.InstructorID = c.InstructorID
#     GROUP BY t.Instructor;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 766 rows affected.
# [('Anthony Menendez', 'ACCT', 5, 1),
#  ('Kala Seal', 'ACCT', 5, 1),
#  ('Nancy Coster', 'ACCT', 4, 3),
#  ('Youyou Tao', 'ACCT', 4, 3),
#  ('Zining Li', 'ACCT', 3, 5),
#  ('Shan Wang', 'ACCT', 3, 5),
#  ('Susan Elkinawy', 'ACCT', 3, 5),
#  ('Terry Wang', 'ACCT', 0, 8),
#  ('Laurel Franzen', 'ACCT', 0, 8),
#  ('Ace Vo', 'ACCT', 0, 8),
#  ('Ana Gadh', 'ACCT', 0, 8),
#  ('Hai Tran', 'ACCT', 0, 8),
#  ('Yan Zhang', 'ACCT', 0, 8),
#  ('Timothy Haight', 'ACCT', 0, 8),
#  ('Richard Minot', 'ACCT', 0, 8),
#  ('James Plecnik', 'ACCT', 0, 8),
#  (None, 'ACCT', 0, 8),
#  ('Candice Reid', 'ACCT', 0, 8),
#  ('Nathan Chang', 'AERO', 0, 1),
#  ('Magaela Bethune', 'AERO', 0, 1),
#  ('Luke Preslar', 'AERO', 0, 1),
#  ('Sarah Garcia', 'AERO', 0, 1),
#  ('William Washington', 'AFAM', 4, 1),
#  ('Malcolm Frierson', 'AFAM', 3, 2),
#  ('Marne Campbell', 'AFAM', 3, 2),
#  ('Jennifer Williams', 'AFAM', 2, 4),
#  ('Andrew Dilts', 'AFAM', 2, 4),
#  ('Adilifu Nama', 'AFAM', 2, 4),
#  ('Kaelyn Sabal-Wilson', 'AFAM', 2, 4),
#  ('Eddie Becton', 'AFAM', 2, 4),
#  ('Mariko Rooks', 'AFAM', 1, 9),
#  ('Jalylah Burrell', 'AFAM', 0, 10),
#  ('Thomas Klein', 'AFAM', 0, 10),
#  ('Garrison Paige', 'AFAM', 0, 10),
#  ('Christopher SooHoo', 'ANIM', 2, 1),
#  ('Shane Acker', 'ANIM', 2, 1),
#  ('Sydney Bright', 'ANIM', 1, 3),
#  ('Han Day', 'ANIM', 0, 4),
#  ('Tiffany Yee', 'ANIM', 0, 4),
#  ('Robert Calcagno', 'ANIM', 0, 4),
#  ('Joshua Morgan', 'ANIM', 0, 4),
#  ('Jose Garcia Moreno', 'ANIM', 0, 4),
#  ('Eugene Yelchin', 'ANIM', 0, 4),
#  ('Matthew Sheehan', 'ANIM', 0, 4),
#  ('Patrice Pinardo', 'ANIM', 0, 4),
#  ('Sam Goff', 'ANIM', 0, 4),
#  ('Pavel Cantu', 'ANIM', 0, 4),
#  ('Edward Park', 'APAM', 4, 1),
#  ('Lan Ngo', 'APAM', 2, 2),
#  ('Neelanjana Banerjee', 'APAM', 2, 2),
#  ('My Chau', 'APAM', 0, 4),
#  ('Curtiss Takada Rooks', 'APAM', 0, 4),
#  ('Heangjin Park', 'APAM', 0, 4),
#  ('Nadia Kim', 'APAM', 0, 4),
#  ('Heidi Fessler', 'ARHS', 7, 1),
#  ('Kirstin Noreen', 'ARHS', 4, 2),
#  ('Charles Peterson', 'ARHS', 4, 2),
#  ('Johannes Stahl', 'ARHS', 0, 4),
#  ('Masha Kowell', 'ARHS', 0, 4),
#  ('Damon Willick', 'ARHS', 0, 4),
#  ('Beth Rosenblum', 'ARHS', 0, 4),
#  ('Melody Rodari', 'ARHS', 0, 4),
#  ('Qianru Li', 'ARHS', 0, 4),
#  ('Diane Meyer', 'ART', 4, 1),
#  ('Ann Le', 'ART', 4, 1),
#  ('Jane Brucker', 'ART', 3, 3),
#  ('Aliaa El Sandouby', 'ART', 2, 4),
#  ('Glenn Grishkoff', 'ART', 2, 4),
#  ('William Pupa', 'ART', 2, 4),
#  ('Tyler Ferreira', 'ART', 2, 4),
#  ('Brian Moss', 'ART', 2, 4),
#  ('Molly Corey', 'ART', 1, 9),
#  ('Margaret White', 'ART', 0, 10),
#  ('Dmitry Kemell', 'ART', 0, 10),
#  ('Selwa Sweidan', 'ART', 0, 10),
#  ('Masaru Suzuki', 'ART', 0, 10),
#  ('Jenna Bonistalli', 'ART', 0, 10),
#  ('Saeri Dobson', 'ART', 0, 10),
#  ('Teresa Lenihan', 'ART', 0, 10),
#  ('Paloma Barhaugh-Bordas', 'ART', 0, 10),
#  ('May Roded', 'ART', 0, 10),
#  ('Andrew Kutchera', 'ART', 0, 10),
#  ('Kathleen McLaughlin', 'ART', 0, 10),
#  ('DJ Watson', 'ART', 0, 10),
#  ('Rev. Michael Tang', 'ART', 0, 10),
#  ('Joshua Caffrey', 'ART', 0, 10),
#  ('Lindsay Lindberg', 'ART', 0, 10),
#  ('Alex Calle', 'ART', 0, 10),
#  ('David Russell', 'ART', 0, 10),
#  ('Christina Webb', 'ART', 0, 10),
#  ('Gladys Mac', 'ASPA', 0, 1),
#  ('Nicholas Brown', 'ASPA', 0, 1),
#  ('Thuy Le', 'ASPA', 0, 1),
#  ('Jordan Christopher', 'ASPA', 0, 1),
#  ('Zoe Slatoff', 'ASPA', 0, 1),
#  ('TOM Plate', 'ASPA', 0, 1),
#  ('Ying Sai', 'BADM', 4, 1),
#  ('Ingrid Greene', 'BADM', 3, 2),
#  ('Pamela Sklar', 'BADM', 2, 3),
#  ('Jeffrey Anderson', 'BADM', 0, 4),
#  ('David Moore', 'BADM', 0, 4),
#  ('Sung Sohn', 'BADM', 0, 4),
#  ('Sunil Murthy', 'BCOR', 4, 1),
#  ('Sona Gala', 'BCOR', 4, 1),
#  ('David Offenberg', 'BCOR', 3, 3),
#  ('Matt Stefl', 'BCOR', 3, 3),
#  ('Li Dai', 'BCOR', 2, 5),
#  ('Brandon Shamim', 'BCOR', 2, 5),
#  ('Bassam Farah', 'BCOR', 2, 5),
#  ('Lisa Daggett', 'BCOR', 2, 5),
#  ('Melissa Fitzpatrick', 'BCOR', 2, 5),
#  ('Jade Chen', 'BCOR', 2, 5),
#  ('Francisco Valle', 'BCOR', 2, 5),
#  ('William Kinsella', 'BCOR', 2, 5),
#  ('Arin Brahma', 'BCOR', 2, 5),
#  ('Yasaman Ghasemi', 'BCOR', 2, 5),
#  ('Anna Papazian', 'BCOR', 2, 5),
#  ('Chun Lee', 'BCOR', 2, 5),
#  ('Sina Zare', 'BCOR', 2, 5),
#  ('Kelly Watson', 'BCOR', 2, 5),
#  ('Dominique Braxton', 'BCOR', 2, 5),
#  ('Albaro Ibarra', 'BCOR', 2, 5),
#  ('Trevor Wiseman', 'BCOR', 1, 21),
#  ('Dustin Reece', 'BCOR', 1, 21),
#  ('Alfredo Romero', 'BCOR', 0, 23),
#  ('Kenneth Summers', 'BCOR', 0, 23),
#  ('Noriko Sato Ward', 'BCOR', 0, 23),
#  ('Linda Simon', 'BCOR', 0, 23),
#  ('Armando Paz', 'BCOR', 0, 23),
#  ('Jamie Weissenborn', 'BCOR', 0, 23),
#  ('Amy Komins', 'BCOR', 0, 23),
#  ('Kevin McConahey', 'BCOR', 0, 23),
#  ('Dennis Draper', 'BCOR', 0, 23),
#  ('Arthur Gross Schaefer', 'BCOR', 0, 23),
#  ('Shaghayegh Balali', 'BCOR', 0, 23),
#  ('Sam Mukherjee', 'BCOR', 0, 23),
#  ('Mostafa Mesgari Mashhadi', 'BCOR', 0, 23),
#  ('Edward Lee', 'BCOR', 0, 23),
#  ('Thomas Bielek', 'BCOR', 0, 23),
#  ('Anatoly Zhuplev', 'BCOR', 0, 23),
#  ('Jeffrey Thies', 'BCOR', 0, 23),
#  ('Madhubalan Viswanathan', 'BCOR', 0, 23),
#  ('Maria Vasquez', 'BIOE', 9, 1),
#  ("Roberto Dell'Oro", 'BIOE', 1, 2),
#  ('Gianna McMillan', 'BIOE', 0, 3),
#  ('Thomas Cunningham', 'BIOE', 0, 3),
#  ('Jennifer Gumer', 'BIOE', 0, 3),
#  ('Sarah Bittick', 'BIOL', 13, 1),
#  ('Michelle Lum', 'BIOL', 11, 2),
#  ('Cory Evans', 'BIOL', 11, 2),
#  ('Carl Urbinati', 'BIOL', 10, 4),
#  ('Wendy Binder', 'BIOL', 9, 5),
#  ('Kristen Covino', 'BIOL', 9, 5),
#  ('Cheryl Hertz', 'BIOL', 9, 5),
#  ('Nancy Fujishige', 'BIOL', 8, 8),
#  ('Eric Strauss', 'BIOL', 8, 8),
#  ('Maxellende Ezin', 'BIOL', 8, 8),
#  ('Carolyn Viviano', 'BIOL', 6, 11),
#  ('Deepa Dabir', 'BIOL', 0, 12),
#  ('Demian Willette', 'BIOL', 0, 12),
#  ('Tatiana Kuzmenko', 'BIOL', 0, 12),
#  ('Kam Dahlquist', 'BIOL', 0, 12),
#  ('Philippa Drennan', 'BIOL', 0, 12),
#  ('Charles Higgins', 'BIOL', 0, 12),
#  ('Chris Caughman', 'BLAW', 0, 1),
#  ('Marcy Newman', 'BLAW', 0, 1),
#  ('Andrea Schlaerth', 'BSAN', 6, 1),
#  ('Gregory Lontok', 'BSAN', 4, 2),
#  ('Linda Leon', 'BSAN', 2, 3),
#  ('Ronald Duncan', 'BSAN', 0, 4),
#  ('Richard Zhen Tang', 'BSAN', 0, 4),
#  ('Saori Shiraki', 'CATH', 10, 1),
#  ('William Shaules', 'CATH', 4, 2),
#  ('Mark Aloysius', 'CATH', 4, 2),
#  ('Michael Courey', 'CATH', 4, 2),
#  ('Charles Jurgensmeier', 'CATH', 4, 2),
#  ('Cecilia Gonzalez-Andrieu', 'CATH', 4, 2),
#  ('Layla Karst', 'CATH', 4, 2),
#  ('David Kovacs', 'CATH', 4, 2),
#  ('Kim Harris', 'CATH', 4, 2),
#  ('Sean Dempsey', 'CATH', 3, 10),
#  ('Mark Diamond', 'CATH', 3, 10),
#  ('Christopher Kaczor', 'CATH', 3, 10),
#  ('Cathleen McGrath', 'CATH', 3, 10),
#  ('Eric Perl', 'CATH', 3, 10),
#  ('Martin Nemoianu', 'CATH', 3, 10),
#  ('Serhiy Hovorun', 'CATH', 2, 16),
#  ('Marc Reeves', 'CATH', 1, 17),
#  ('Brett Hoover', 'CATH', 0, 18),
#  ('Rebecca Sager', 'CATH', 0, 18),
#  ('Erin Stackle', 'CATH', 0, 18),
#  ('Brian Michael Reedy', 'CATH', 0, 18),
#  ('Robert Allison', 'CATH', 0, 18),
#  ('Robert Senter', 'CHEM', 13, 1),
#  ('Nicole Bouvier-Brown', 'CHEM', 9, 2),
#  ('Jeremy McCallum', 'CHEM', 8, 3),
#  ('Sarah Mitchell', 'CHEM', 8, 3),
#  ('Thomas Reilly', 'CHEM', 6, 5),
#  ('Lambert Doezema', 'CHEM', 5, 6),
#  ('Vanessa Diaz', 'CHEM', 4, 7),
#  ('Priscilla Leiva', 'CHEM', 3, 8),
#  ('Tina Choe', 'CHEM', 2, 9),
#  ('Emily Jarvis', 'CHEM', 2, 9),
#  ('David Moffet', 'CHEM', 0, 11),
#  ('Steve Heller', 'CHEM', 0, 11),
#  ('Ryan Hunt', 'CHEM', 0, 11),
#  ('Katie Mouzakis', 'CHEM', 0, 11),
#  ('Yu Li', 'CHIN', 4, 1),
#  ('Michael Manoogian', 'CHIN', 3, 2),
#  ('Christopher Gipson', 'CIVL', 4, 1),
#  ('Rachel Adams', 'CIVL', 3, 2),
#  ('Joseph Weber', 'CIVL', 2, 3),
#  ('William Trott', 'CIVL', 1, 4),
#  ('Joseph Reichenberger', 'CIVL', 0, 5),
#  ('Katerina Zacharia', 'CLAR', 5, 1),
#  ('Elliott Piros', 'CLAR', 2, 2),
#  ('Ben Radcliffe', 'CLAR', 2, 2),
#  ('Corrina Laughlin', 'CLAR', 0, 4),
#  ('Todd Martinez', 'CLAR', 0, 4),
#  ('Caroline Sauvage', 'CLAR', 0, 4),
#  ('Sandibel Borges', 'CLST', 3, 1),
#  ('Xiaojing Sun', 'CLST', 3, 1),
#  ('Claudia Sandoval', 'CLST', 3, 1),
#  ('Sandy Ko', 'CLST', 2, 4),
#  ('Eliza Rodriguez', 'CLST', 0, 5),
#  ('Ruben Martinez', 'CLST', 0, 5),
#  ('Fernando Guerra', 'CLST', 0, 5),
#  ('Hossein Asghari', 'CMSI', 4, 1),
#  ('B.J. Johnson', 'CMSI', 3, 2),
#  ('Jordan Freitas', 'CMSI', 2, 3),
#  ('Andrew Forney', 'CMSI', 2, 3),
#  ('Tyler Edmiston', 'CMSI', 1, 5),
#  ('Rosalynde Loo', 'CMSI', 0, 6),
#  ('Christina Dempsey', 'CMSI', 0, 6),
#  ('Katherine Lucas', 'CMSI', 0, 6),
#  ('John David Dionisio', 'CMSI', 0, 6),
#  ('Krishnamurthy Narayanaswamy', 'CMSI', 0, 6),
#  ('Damon Hines', 'CMST', 3, 1),
#  ('Mandy Korpusik', 'CMST', 3, 1),
#  ('Rebecca Avalos', 'CMST', 3, 1),
#  ('Michael Genovese', 'CMST', 3, 1),
#  ('Christopher Finlay', 'CMST', 3, 1),
#  ('Therese Edwards', 'CMST', 3, 1),
#  ('Kyra Pearson', 'CMST', 3, 1),
#  ('Patricia Oliver', 'CMST', 3, 1),
#  ('Jason Jarvis', 'CMST', 3, 1),
#  ('Nina Lozano', 'CMST', 3, 1),
#  ('Matthew Dewey', 'CMST', 3, 1),
#  ('Kristo Gobin', 'CMST', 3, 1),
#  ('James Bunker', 'CMST', 3, 1),
#  ('Darrin Murray', 'CMST', 3, 1),
#  ('Craig Rich', 'CMST', 2, 15),
#  ('Sergio Juarez', 'CMST', 2, 15),
#  ('Shelby Giles', 'CMST', 2, 15),
#  ('Amanda Whidden', 'CMST', 2, 15),
#  ('Shaun Anderson', 'CMST', 2, 15),
#  ('Caroline LaMonda', 'CMST', 1, 20),
#  ('Kathleen Norris', 'CMST', 1, 20),
#  ('Dudley Gray', 'CMST', 1, 20),
#  ('Kristin Doidge', 'CMST', 0, 23),
#  ('Delaram Yazdan Sepas', 'CMST', 0, 23),
#  ('Michele Raphael', 'CMST', 0, 23),
#  ('Alissa Cruz', 'CMST', 0, 23),
#  ('Judy Battaglia', 'CMST', 0, 23),
#  ('Meng Li', 'CMST', 0, 23),
#  ('Laura Smyth', 'DANC', 5, 1),
#  ('Kristen Smiarowski', 'DANC', 3, 2),
#  ('James Gregg', 'DANC', 3, 2),
#  ('Carlos Villegas', 'DANC', 2, 4),
#  ('Meric Keskinel', 'DANC', 2, 4),
#  ('June Duarte', 'DANC', 1, 6),
#  ('Mavis Rode', 'DANC', 1, 6),
#  ('Lauren Caplan', 'DANC', 0, 8),
#  ('Taryn Vander Hoop', 'DANC', 0, 8),
#  ('Stephanie Liapis', 'DANC', 0, 8),
#  ('Tashara Gavin-Moorehead', 'DANC', 0, 8),
#  ('Marquisa Gardner', 'DANC', 0, 8),
#  ('Sarah Thomason', 'DANC', 0, 8),
#  ('James De Vries', 'DANC', 0, 8),
#  ('Geri Brown', 'DANC', 0, 8),
#  ('Mayuri Bhandari', 'DANC', 0, 8),
#  ('Aaron Chavez', 'DANC', 0, 8),
#  ('Monti Ellison', 'DANC', 0, 8),
#  ('Mary Trunk', 'DANC', 0, 8),
#  ('Jermaine McGhee', 'DANC', 0, 8),
#  ('Laura Berg', 'DANC', 0, 8),
#  ('Darrian OReilly', 'DANC', 0, 8),
#  ('Eric Stretch', 'DANC', 0, 8),
#  ('Veronica Caudillo', 'DANC', 0, 8),
#  ('Maureen Gonzales', 'DANC', 0, 8),
#  ('Sarah Mata-Gabor', 'DANC', 0, 8),
#  ('Bernard Brown', 'DANC', 0, 8),
#  ('Jill Nunes Jensen', 'DANC', 0, 8),
#  ('Patrick Rago', 'DANC', 0, 8),
#  ('Steve Zee', 'DANC', 0, 8),
#  ('Wesley Chew', 'DANC', 0, 8),
#  ('Anna Terzyan', 'ECON', 4, 1),
#  ('Nyema Guannu', 'ECON', 4, 1),
#  ('Eric Young', 'ECON', 4, 1),
#  ('Michelle Miller', 'ECON', 4, 1),
#  ('Dorothea Herreiner', 'ECON', 3, 5),
#  ('Shirin Mollah', 'ECON', 3, 5),
#  ('Prachi Jain', 'ECON', 2, 7),
#  ('Carla Moreno', 'ECON', 2, 7),
#  ('Swarup Joshi', 'ECON', 2, 7),
#  ('Emma Davis', 'ECON', 2, 7),
#  ('Konstantin Platonov', 'ECON', 0, 11),
#  ('Inas Kelly', 'ECON', 0, 11),
#  ('Michelle Kiser', 'ECON', 0, 11),
#  ('Victor Seca Diaz', 'ECON', 0, 11),
#  ('Graham Beattie', 'ECON', 0, 11),
#  ('Jennifer Leal', 'ECON', 0, 11),
#  ('Jin Xu', 'ECON', 0, 11),
#  ('George Sarraf', 'ECON', 0, 11),
#  ('Kittiyaratch Thanakornmonkkonchai', 'ECON', 0, 11),
#  ('Luoyi Xiao', 'ECON', 0, 11),
#  ('Brandon De Bruhl', 'ECON', 0, 11),
#  ('Fan Liang', 'ECON', 0, 11),
#  ('Brendan Smith', 'EDES', 3, 1),
#  ('Annette Hernandez', 'EDES', 0, 2),
#  ('Nadja Conway', 'EDES', 0, 2),
#  ('Barbara Marino', 'EDLA', 6, 1),
#  ('William Parham', 'EDLA', 3, 2),
#  ('Ernesto Colin', 'EDLA', 2, 3),
#  ('Steven Nygaard', 'EDLA', 1, 4),
#  ('Christopher Cormier', 'EDLA', 1, 4),
#  ('Yvette Lapayese', 'EDLA', 1, 4),
#  ('Joy Ee', 'EDLA', 0, 7),
#  ('Julia Wade', 'EDLA', 0, 7),
#  ('Rebecca Stephenson', 'EDLA', 0, 7),
#  ('Kenzo Sung', 'EDLA', 0, 7),
#  ('Dolores Delgado Bernal', 'EDLA', 0, 7),
#  ('Karie Huchting', 'EDLA', 0, 7),
#  ('Kyo Yamashiro', 'EDLA', 0, 7),
#  ('William Perez', 'EDLA', 0, 7),
#  ("Franca Dell'Olio", 'EDLA', 0, 7),
#  ('Cynthia Alcantar', 'EDLA', 0, 7),
#  ('Rachelle Henry-Hendricks', 'EDLA', 0, 7),
#  ('Antonio Felix', 'EDLA', 0, 7),
#  ('Steven Mitchell', 'EDLA', 0, 7),
#  ('Leroy Gaines', 'EDLA', 0, 7),
#  ('Lauren Casella', 'EDLA', 0, 7),
#  ('Manuel Ponce', 'EDLA', 0, 7),
#  ('Chelsea Brown', 'EDLA', 0, 7),
#  ('John Orozco', 'EDLA', 0, 7),
#  ('Sabrina Merritt', 'EDLA', 0, 7),
#  ('Patrick Furlong', 'EDLA', 0, 7),
#  ('Jamal Epperson', 'EDLA', 0, 7),
#  ('Isabel Villalobos-Galeana', 'EDLA', 0, 7),
#  ('Kandis Jernigan', 'EDLA', 0, 7),
#  ('Andrea Niemi', 'EDLA', 0, 7),
#  ('Csilla Samay', 'EDLA', 0, 7),
#  ('Sabrina Moore', 'EDLA', 0, 7),
#  ('Ellen Ensher', 'EDLP', 3, 1),
#  ('Frank Sheppard', 'EDSP', 4, 1),
#  ('Dana Resnick', 'EDSP', 4, 1),
#  ('Andrea Odinov', 'EDSP', 3, 3),
#  ('Katharine Noon', 'EDSP', 3, 3),
#  ('Tory Smith', 'EDSP', 2, 5),
#  ('Lawrence Lacey', 'EDSP', 2, 5),
#  ('Sean Fenton', 'EDSP', 2, 5),
#  ('Keiana Richard', 'EDSP', 0, 8),
#  ('Marc Colera', 'EDSP', 0, 8),
#  ('Meagan Prahl', 'EDSP', 0, 8),
#  ('Nenad Pervan', 'EDSP', 0, 8),
#  ('Tammie Merheb-Chavez', 'EDSP', 0, 8),
#  ('Dione H Lebhar', 'EDSP', 0, 8),
#  ('Christine Breihan', 'EDSP', 0, 8),
#  ('Elizabeth Henley', 'EDTL', 1, 1),
#  ('Doris Baizley', 'EDTL', 0, 2),
#  ('Arnab Banerji', 'EDTL', 0, 2),
#  ('Diane Benedict', 'EDTL', 0, 2),
#  ('Stacey Cabaj', 'EDUR', 3, 1),
#  ('Ronnie Clark', 'EDUR', 1, 2),
#  ('Mary McCusker', 'EDUR', 1, 2),
#  ('Robert Hillig', 'EDUR', 0, 4),
#  ('Jaime Gray', 'EDUR', 0, 4),
#  ('Leigh Kennicott', 'EDUR', 0, 4),
#  ('Paulo Lima', 'EDUR', 0, 4),
#  ('Catharine Dada', 'EDUR', 0, 4),
#  ('Mark Seldis', 'EDUR', 0, 4),
#  ('Gustavo Vejarano', 'EECE', 0, 1),
#  ('John Poladian', 'EECE', 0, 1),
#  ('Jie Xu', 'EECE', 0, 1),
#  ("Jason D'Mello", 'ENGL', 5, 1),
#  ('Margarete Feinstein', 'ENGL', 5, 1),
#  ('Alexander Glosenberg', 'ENGL', 3, 3),
#  ('Julia Lee', 'ENGL', 3, 3),
#  ('Robin Miskolcze', 'ENGL', 2, 5),
#  ('Kevin Peters', 'ENGL', 2, 5),
#  ('Bryan Wisch', 'ENGL', 2, 5),
#  ('Judy Park', 'ENGL', 2, 5),
#  ('Rochelle Webb', 'ENGL', 1, 9),
#  ('Holli Levitsky', 'ENGL', 0, 10),
#  ('Petra Taylor', 'ENGL', 0, 10),
#  ('Kelly Younger', 'ENGL', 0, 10),
#  ('Stephen Shepherd', 'ENGL', 0, 10),
#  ('Dermot Ryan', 'ENGL', 0, 10),
#  ('Michelle Bitting', 'ENGL', 0, 10),
#  ('Sarah Maclay', 'ENGL', 0, 10),
#  ('Aimee Ross-Kilroy', 'ENGL', 0, 10),
#  ('Alana Faagai', 'ENGL', 0, 10),
#  ('Alexandra Neel', 'ENGR', 2, 1),
#  ('Hannah Sawyerr', 'ENGR', 0, 2),
#  ('Jeffrey Nazzaro', 'ENGR', 0, 2),
#  ('Thomas Ford', 'ENSI', 1, 1),
#  ('Mark Macedo', 'ENTR', 2, 1),
#  ('Alessandro Varotto', 'ENTR', 1, 2),
#  ('Michael Wojciechowski', 'ENTR', 0, 3),
#  ('Marcus Crews', 'ENTR', 0, 3),
#  ('Jim Wagner', 'ENTR', 0, 3),
#  ('Lewis Jaffe', 'ENTR', 0, 3),
#  ('Jerilyn Lopez Mendoza', 'ENTR', 0, 3),
#  ('Jennifer Longnion', 'ENTR', 0, 3),
#  ('Peter Hoffman', 'ENVS', 10, 1),
#  ('Rebecca Wall', 'EVST', 4, 1),
#  ('Bernadette Musetti', 'EVST', 3, 2),
#  ('Jonas Mureika', 'FFYS', 5, 1),
#  ('Kevin Wetmore', 'FFYS', 5, 1),
#  ('Elham Ghashghai', 'FFYS', 4, 3),
#  ('Nigel Raab', 'FFYS', 4, 3),
#  ('Michael Daley', 'FFYS', 3, 5),
#  ('Elizabeth Drummond', 'FFYS', 3, 5),
#  ('Laura Huffman', 'FFYS', 3, 5),
#  ('Catherine Peters', 'FFYS', 2, 8),
#  ('Daniel Speak', 'FFYS', 2, 8),
#  ('Robin Wilson', 'FFYS', 2, 8),
#  ('Zaki Eusufzai', 'FFYS', 2, 8),
#  ('Sylvia Zamora', 'FFYS', 2, 8),
#  ('Yanjie Wang', 'FFYS', 2, 8),
#  ('Amir Hussain', 'FFYS', 1, 14),
#  ('Divine Gbagbo', 'FFYS', 0, 15),
#  ('Vandana Thadani', 'FFYS', 0, 15),
#  ('Daphnie Sicre', 'FFYS', 0, 15),
#  ('Eric Magnuson', 'FFYS', 0, 15),
#  ('Joseph LaBrie', 'FFYS', 0, 15),
#  ('Timothy Williamson', 'FFYS', 0, 15),
#  ('Christina Bogdanou', 'FFYS', 0, 15),
#  ('Beth Hynes', 'FFYS', 0, 15),
#  ('Mairead Sullivan', 'FFYS', 0, 15),
#  ('Paola Moscarelli', 'FFYS', 0, 15),
#  ('Carissa Phillips-Garrett', 'FFYS', 0, 15),
#  ('Micah Officer', 'FNCE', 1, 1),
#  ('Anthony Beaudoin', 'FNCE', 0, 2),
#  ('Marc Lony', 'FREN', 1, 1),
#  ('Veronique Flambard-Weisbart', 'FREN', 0, 2),
#  ('Kenneth Provencher', 'FTVS', 8, 1),
#  ('Gloria Shin', 'FTVS', 6, 2),
#  ('Sharon Mooney', 'FTVS', 5, 3),
#  ('Susan Scheibler', 'FTVS', 3, 4),
#  ('Stephen Ujlaki', 'FTVS', 3, 4),
#  ('Kimberly Icreverzi', 'FTVS', 2, 6),
#  ('Richard Hadley', 'FTVS', 2, 6),
#  ('Robert Simmons', 'FTVS', 1, 8),
#  ('Dan Watanabe', 'FTVS', 1, 8),
#  ('Raymond Greene', 'FTVS', 1, 8),
#  ('Dawn Fratini', 'FTVS', 0, 11),
#  ('Allison Ross', 'FTVS', 0, 11),
#  ('Courtney White', 'FTVS', 0, 11),
#  ('Tyler Quick', 'FTVS', 0, 11),
#  ('Jacob Bohrod', 'FTVS', 0, 11),
#  ('Robert DeMaio', 'FTVS', 0, 11),
#  ("Aine O'Healy", 'FTVS', 0, 11),
#  ('Mikki Kressbach', 'FTVS', 0, 11),
#  ('Christopher Cappelli', 'GRMN', 4, 1),
#  ('Hawley Almstedt', 'GRMN', 0, 2),
#  ('Udo Steves', 'GRMN', 0, 2),
#  ('Sarah Strand', 'HHSC', 4, 1),
#  ('Jenevieve Roper', 'HHSC', 4, 1),
#  ('Alexandra Sturm', 'HHSC', 4, 1),
#  ('Todd Shoepe', 'HHSC', 3, 4),
#  ('Robert Musci', 'HHSC', 3, 4),
#  ('David Quam', 'HHSC', 0, 6),
#  ('Hassan Movahedi', 'HHSC', 0, 6),
#  ('Caio de Sousa Silva', 'HHSC', 0, 6),
#  ('Margarita Ochoa', 'HIST', 4, 1),
#  ('Robin Wang', 'HIST', 3, 2),
#  ('James Taylor', 'HIST', 3, 2),
#  ('Nicolas Rosenthal', 'HIST', 2, 4),
#  ('Lauren Cole', 'HIST', 2, 4),
#  ('Kevin McDonald', 'HIST', 2, 4),
#  ('Andreas Geyr', 'HIST', 0, 7),
#  ('Ali Olomi', 'HIST', 0, 7),
#  ('Amy Woodson-Boulton', 'HNRS', 2, 1),
#  ('Jason Baehr', 'HNRS', 2, 1),
#  ('Timothy Shanahan', 'HNRS', 2, 1),
#  ('Ian Moore', 'HNRS', 1, 4),
#  ('Cassidy Alvarado', 'HNRS', 0, 5),
#  ('David Clawson', 'HNRS', 0, 5),
#  ('Eric Swanson', 'HNRS', 0, 5),
#  ('Mark Anderson', 'HSEG', 2, 1),
#  ('Anthony Perron', 'HSEG', 2, 1),
#  ('Alexander Zambrano', 'ICLA', 1, 1),
#  ('Jeno Hodi', 'IFTV', 0, 1),
#  ('Velitchka Kaltcheva', 'ISBA', 3, 1),
#  ('Yongsun Paik', 'ISBA', 2, 2),
#  ('Jeffrey Gale', 'ISBA', 0, 3),
#  ('Christen Johnson', 'ISBA', 0, 3),
#  ('Patricia Meyer', 'ISOE', 3, 1),
#  ('Hiromi Kinjo', 'ITAL', 3, 1),
#  ('Gil Klein', 'JAPN', 4, 1),
#  ('L. Arik Greenberg', 'JAPN', 0, 2),
#  ('Cat Schuknecht', 'JOUR', 0, 1),
#  ('Benjamin Gottlieb', 'JOUR', 0, 1),
#  ('Steven Neal', 'JOUR', 0, 1),
#  ('Yoshikazu Ysa', 'JOUR', 0, 1),
#  ('Christopher Keller', 'JOUR', 0, 1),
#  ('Lauren Smart', 'JOUR', 0, 1),
#  ('Ky Henderson', 'JOUR', 0, 1),
#  ('Laila Muhammad', 'JOUR', 0, 1),
#  ('Jon Rou', 'JOUR', 0, 1),
#  ('John Kissell', 'JOUR', 0, 1),
#  ('Emily Plutsky', 'JOUR', 0, 1),
#  ('Roy Fisher', 'JWST', 5, 1),
#  ('Kevin Curran', 'JWST', 0, 2),
#  ('Thomas Laurent', 'MATH', 3, 1),
#  ('Vivian Lezak', 'MATH', 3, 1),
#  ('Christina Eubanks-Turner', 'MATH', 3, 1),
#  ('Blake Mellor', 'MATH', 3, 1),
#  ('Mobashera Hallam', 'MATH', 3, 1),
#  ('Le Wang', 'MATH', 2, 6),
#  ('Junyuan Lin', 'MATH', 2, 6),
#  ('Edward Mosteig', 'MATH', 2, 6),
#  ('Joshua Hallam', 'MATH', 2, 6),
#  ('Yanping Ma', 'MATH', 2, 6),
#  ('Patrick Shanahan', 'MATH', 1, 11),
#  ('Alissa Crans', 'MATH', 0, 12),
#  ('Roberto Martinez', 'MATH', 0, 12),
#  ('Anna Bargagliotti', 'MATH', 0, 12),
#  ('Ben Fitzpatrick', 'MATH', 0, 12),
#  ('Robert Rovetti', 'MATH', 0, 12),
#  ('Rafiqul Noorani', 'MATH', 0, 12),
#  ('Mahsa Ebrahim', 'MATH', 0, 12),
#  ('Tony Kmetty', 'MBAA', 3, 1),
#  ('Robert Kritzler', 'MBAA', 2, 2),
#  ('Robbie Nakatsu', 'MBAA', 2, 2),
#  ('Andrew Rohm', 'MBAA', 2, 2),
#  ('Melissa Gerber', 'MBAA', 0, 5),
#  ('Dong Chen', 'MBAA', 0, 5),
#  ('Yu Hui Lai', 'MBAA', 0, 5),
#  ('Karen Ellis', 'MBAC', 4, 1),
#  ('Juan Mah y Busch', 'MBAF', 2, 1),
#  ('Bryan Wuest', 'MBAP', 7, 1),
#  ('Albert Minette', 'MDGK', 12, 1),
#  ('Marisa De Silva', 'MDGK', 11, 2),
#  ('Martha Masters', 'MDGK', 10, 3),
#  ('Barbara Dyer', 'MDGK', 9, 4),
#  ('Joseph Dhanens', 'MDGK', 0, 5),
#  ('Kristi Lobitz', 'MDLG', 10, 1),
#  ('Aaron Smith', 'MECH', 10, 1),
#  ('James Nokes', 'MECH', 0, 2),
#  ('Virginia Figueiredo', 'MECH', 0, 2),
#  ('Rik Noyce', 'MECH', 0, 2),
#  ('Omar Es-Said', 'MECH', 0, 2),
#  ('Tent Bordeenithikasem', 'MECH', 0, 2),
#  ('Jennifer Elliott', 'MECH', 0, 2),
#  ('Alan Paul', 'MECH', 0, 2),
#  ('Matt Siniawski', 'MECH', 0, 2),
#  ('Robert Winsor', 'MFTH', 2, 1),
#  ('Michael Peditto', 'MFTH', 0, 2),
#  ('My Bui', 'MFTH', 0, 2),
#  ('Myounghee Moon', 'MFTH', 0, 2),
#  ('Mitchell Rufca', 'MGMT', 0, 1),
#  ('Mark Fotohabadi', 'MGMT', 0, 1),
#  ('Natalie Ortiz', 'MRKT', 3, 1),
#  ('Nicholas Virginio', 'MRKT', 1, 2),
#  ('Kimberly Rohm', 'MRKT', 1, 2),
#  ('Mitchell Hamilton', 'MRKT', 1, 2),
#  ('Paul Santello', 'MRKT', 0, 5),
#  ('Farhoud Meybodi', 'MRKT', 0, 5),
#  ('Sean Williams', 'MRKT', 0, 5),
#  ('Wojciech Kocyan', 'MUSC', 10, 1),
#  ('Tania Fleischer', 'MUSC', 9, 2),
#  ('Mark Saya', 'MUSC', 4, 3),
#  ('Dee Filecia', 'MUSC', 2, 4),
#  ('Kenneth Rudnick', 'MUSC', 1, 5),
#  ('Gwang Kim', 'MUSC', 0, 6),
#  ('Nicole McCabe', 'MUSC', 0, 6),
#  ('Joseph Paguio', 'MUSC', 0, 6),
#  ('Kenichiro Aiso', 'MUSC', 0, 6),
#  ('Janet Favreau', 'MUSC', 0, 6),
#  ('Stella Cho', 'MUSC', 0, 6),
#  ('Shanon Zusman', 'MUSC', 0, 6),
#  ('Hyunju Hwang', 'MUSC', 0, 6),
#  ('Todd Harper', 'MUSC', 0, 6),
#  ('Ernest Harrison', 'MUSC', 0, 6),
#  ('Jeff Phillips', 'ORNT', 4, 1),
#  ('Michael Patzia', 'ORNT', 3, 2),
#  ('David Berube', 'ORNT', 2, 3),
#  ('Brad Stone', 'ORNT', 1, 4),
#  ('Dirk Lanzerath', 'ORNT', 0, 5),
#  ('John Bulman', 'ORNT', 0, 5),
#  ('Emily Hawkins', 'ORNT', 0, 5),
#  ('Zahrasadat Alavi', 'ORNT', 0, 5),
#  ('Rajiv Uttamchandani', 'ORNT', 0, 5),
#  ('Rachel Waterstradt', 'ORNT', 0, 5),
#  ('Marcela Garcia Romero', 'ORNT', 0, 5),
#  ('Hugh Blake', 'ORNT', 0, 5),
#  ('Vicente Munoz-Reja Alonso', 'ORNT', 0, 5),
#  ('Richard Fox', 'PHIL', 4, 1),
#  ('Feryal Cherif', 'PHIL', 3, 2),
#  ('Alexander Diones', 'PHIL', 3, 2),
#  ('Nora Murphy', 'PHIL', 2, 4),
#  ('Gene Park', 'PHIL', 2, 4),
#  ('Jodi Finkel', 'PHIL', 2, 4),
#  ('Kerstin Fisk', 'PHIL', 2, 4),
#  ('Nathan Chan', 'PHIL', 2, 4),
#  ('Adam Thal', 'PHIL', 2, 4),
#  ('Janie Steckenrider', 'PHIL', 2, 4),
#  ('Jennifer Ramos', 'PHIL', 0, 11),
#  ('Brianne Gilbert', 'PHIL', 0, 11),
#  ('Cheryl Grills', 'PHIL', 0, 11),
#  ('David Glazier', 'PHIL', 0, 11),
#  ('Diana Santacrose', 'PHYS', 3, 1),
#  ('Jennifer Abe', 'PHYS', 3, 1),
#  ('Negin Ghavami', 'PHYS', 3, 1),
#  ('Ricardo Machon', 'PHYS', 3, 1),
#  ('Adam Fingerhut', 'PHYS', 2, 5),
#  ('Michael Foy', 'PHYS', 2, 5),
#  ('Chela Willey', 'PHYS', 2, 5),
#  ('Michael Mills', 'PHYS', 2, 5),
#  ('David Hardy', 'PHYS', 2, 5),
#  ('Kayoko Okada', 'PHYS', 1, 10),
#  ('Deanna Cooke', 'PHYS', 1, 10),
#  ('Brett Marroquin', 'PHYS', 0, 12),
#  ('Maire Ford', 'PHYS', 0, 12),
#  ('Gabriele Varieschi', 'PJST', 3, 1),
#  ('Rodger Pardee', 'POLS', 4, 1),
#  ('Teah Goldberg', 'POLS', 3, 2),
#  ('Laura Poladian', 'POLS', 3, 2),
#  ('William McClain', 'POLS', 3, 2),
#  ('Megan Barnes', 'POLS', 3, 2),
#  ('Albert Gasser', 'POLS', 1, 6),
#  ('Edgar Rothermich', 'POLS', 1, 6),
#  ('John Young', 'POLS', 0, 8),
#  ('Matthew Linesch', 'POLS', 0, 8),
#  ('Scott Brownlee', 'POLS', 0, 8),
#  ('Michael Firmont', 'POLS', 0, 8),
#  ('Elizabeth Dewey', 'PROD', 4, 1),
#  ('Mikael Kreuzriegler', 'PROD', 4, 1),
#  ('Kennedy Wheatley', 'PROD', 4, 1),
#  ('Margaret Murphy', 'PROD', 4, 1),
#  ('Vanessa Newell', 'PROD', 3, 5),
#  ('Eugene Brancolini', 'PROD', 3, 5),
#  ('Gregory Ruzzin', 'PROD', 2, 7),
#  ('Leena Pendharkar', 'PROD', 2, 7),
#  ('Karen Smalley', 'PROD', 2, 7),
#  ('Luis Proenca', 'PROD', 1, 10),
#  ('Jessica Livingstone', 'PROD', 0, 11),
#  ('Christopher Murillo', 'PROD', 0, 11),
#  ('Glenn Gebhard', 'PROD', 0, 11),
#  ('Bettina Braun', 'PROD', 0, 11),
#  ('Leon Wiebers', 'PROD', 0, 11),
#  ('Jens Koppelmann', 'PROD', 0, 11),
#  ('Rosanne Korenberg', 'PROD', 0, 11),
#  ('Uta Gaiser-Hood', 'PROD', 0, 11),
#  ('Astrid Menze', 'PROD', 0, 11),
#  ('Donald Zirpola', 'PROD', 0, 11),
#  ('Jonathan Wysocki', 'PROD', 0, 11),
#  ('Susan Faillard', 'PROD', 0, 11),
#  ('Janet Yang', 'PROD', 0, 11),
#  ('Charles Swanson', 'PROD', 0, 11),
#  ('Mischa Livingstone', 'PROD', 0, 11),
#  ('Linh Hua', 'PSYC', 3, 1),
#  ('Kimberly Moekle', 'PSYC', 2, 2),
#  ('Suzanne Larson', 'PSYC', 1, 3),
#  ('Erik Volpe', 'PSYC', 0, 4),
#  ('Courtney Klipp', 'PSYC', 0, 4),
#  ('Carina Flores', 'PSYC', 0, 4),
#  ('Amanda Brockhaus', 'PSYC', 0, 4),
#  ('Mattie Norman', 'PSYC', 0, 4),
#  ('Addison Hall', 'PSYC', 0, 4),
#  ('Daniel Krause', 'PSYC', 0, 4),
#  ('Thomas Dowd', 'PSYC', 0, 4),
#  ('Ana Maradiaga-Bunker', 'PSYC', 0, 4),
#  ('Jeffrey Davis', 'RECA', 4, 1),
#  ('Stacee Comage', 'RECA', 4, 1),
#  ('Marc Pitre', 'RECA', 3, 3),
#  ('Elizabeth Quinn', 'RECA', 2, 4),
#  ('Jonathan Medici', 'RECA', 2, 4),
#  ('Matthew Schlissel', 'RECA', 1, 6),
#  ('Salvador Paskowitz', 'RECA', 0, 7),
#  ('Beth Serlin', 'RECA', 0, 7),
#  ('Jenna Corley', 'RECA', 0, 7),
#  ('Yolanda Buggs', 'RECA', 0, 7),
#  ('Justin Winters', 'RECA', 0, 7),
#  ('Ashley Kreeb', 'RECA', 0, 7),
#  ('Michelle Gillie', 'RECA', 0, 7),
#  ('Thomas Szollosi', 'RECA', 0, 7),
#  ('Karol Hoeffner', 'RHET', 3, 1),
#  ('Mary Kuryla', 'RHET', 3, 1),
#  ('Jay Williams', 'RHET', 2, 3),
#  ('Douglas Eboch', 'RHET', 2, 3),
#  ('Gary Hershberger', 'RHET', 2, 3),
#  ('Laura Harrington', 'RHET', 1, 6),
#  ('David Garber', 'RHET', 1, 6),
#  ('Peter Egan', 'RHET', 1, 6),
#  ('Valerie Mehlschau', 'RHET', 0, 9),
#  ('Stacy Spruill', 'RHET', 0, 9),
#  ('Stephen Kutner', 'RHET', 0, 9),
#  ('Ayser Salman', 'RHET', 0, 9),
#  ('Aaron Skentzos', 'RHET', 0, 9),
#  ('Jonathan Edwards', 'RHET', 0, 9),
#  ('John Strauss', 'RHET', 0, 9),
#  ('Rob Fresco', 'RHET', 0, 9),
#  ('Aaron Mendelsohn', 'RHET', 0, 9),
#  ('Brian May', 'RHET', 0, 9),
#  ('Marianne Krawczyk', 'RHET', 0, 9),
#  ('Adnan Ahmad', 'RHET', 0, 9),
#  ('Aurorae Khoo', 'RHET', 0, 9),
#  ('D.C. Rogers', 'RHET', 0, 9),
#  ('Ernie Bustamante', 'RHET', 0, 9),
#  ('Anne Postman', 'RHET', 0, 9),
#  ('Mark Evan Schwartz', 'RHET', 0, 9),
#  ('Gary Grossman', 'SCEM', 0, 1),
#  ('Monica Cabrera', 'SCWR', 3, 1),
#  ('Karen Hawkins', 'SCWR', 3, 1),
#  ('Nathan Sessoms', 'SCWR', 3, 1),
#  ('Stacy Burns', 'SCWR', 2, 4),
#  ('Stephanie Limoncelli', 'SCWR', 2, 4),
#  ('James Faught', 'SCWR', 2, 4),
#  ('Min Yoo', 'SCWR', 2, 4),
#  ('Tom McNulty', 'SCWR', 1, 8),
#  ('Andrea Plate', 'SCWR', 1, 8),
#  ('Matt Price', 'SCWR', 0, 10),
#  ('Bobby Cohen', 'SCWR', 0, 10),
#  ('Cassie Comley', 'SCWR', 0, 10),
#  ('Rebecca Goodsell', 'SCWR', 0, 10),
#  ('Angel Villasenor', 'SCWR', 0, 10),
#  ('Moses Seenarine', 'SCWR', 0, 10),
#  ('Anna Muraco', 'SCWR', 0, 10),
#  ('Rebeca Acevedo', 'SCWR', 0, 10),
#  ('Antonia Petro', 'SCWR', 0, 10),
#  ('Terese Aceves', 'SCWR', 0, 10),
#  ('Sheri Atwater', 'SCWR', 0, 10),
#  ('Weiko Lin', 'SCWR', 0, 10),
#  ('Nick Thiel', 'SCWR', 0, 10),
#  ('Akin Omotoso', 'SCWR', 0, 10),
#  ('Susan Mora', 'SCWR', 0, 10),
#  ('Dawn Richards', 'SCWR', 0, 10),
#  ('Angela Deterville', 'SCWR', 0, 10),
#  ('Emily Fisher', 'SCWR', 0, 10),
#  ('Anna Winget', 'SYEG', 2, 1),
#  ('James Holmes', 'SYEG', 2, 1),
#  ('Jon Rivera', 'SYEG', 0, 3),
#  ('Christopher Chapple', 'THEA', 4, 1),
#  ('Nirinjan Khalsa', 'THEA', 3, 2),
#  ('Charlotte Radler', 'THEA', 3, 2),
#  ('Sina Kramer', 'THEA', 2, 4),
#  ('Jessica Martinez-Tebbel', 'THEA', 2, 4),
#  ('Stella Oh', 'THEA', 2, 4),
#  ('Jonathan Rothchild', 'THEA', 2, 4),
#  ('Amanda Apgar', 'THEA', 2, 4),
#  ('Danielle Borgia', 'THEA', 2, 4),
#  ('Eric Martin', 'THEA', 2, 4),
#  ('Nancy Pineda-Madrid', 'THEA', 1, 11),
#  ('Tracy Tiemeier', 'THEA', 1, 11),
#  ('Torben Alles', 'THEA', 0, 13),
#  ('Douglas Christie', 'THEA', 0, 13),
#  ('Saqib Hussain', 'THEA', 0, 13),
#  ('Abhishek Jain', 'THEA', 0, 13),
#  ('Christopher Daily', 'THEA', 0, 13),
#  ('Iris Blake', 'THEA', 0, 13),
#  ('Roy Pereira', 'THEA', 0, 13),
#  ('Lori Fazzio', 'THST', 0, 1),
#  ('Judith Carlisle', 'THST', 0, 1)]

# %% [markdown]
# Interesting. Looking through this data shows that many teachers actually have no ratings, even though they appear in Rate My Professor. Students most likely see a professor with many ratings and prefer that professor over others based on the amount of ratings they have. Rate My Professor AND LMU would benefit from RMP creating pages for every teacher, so that students will be more likely to review them and try new teachers.

# %% [markdown]
# My last Question is: What departments on Rate My Professor recieve the best reviews? Specifically, I want to see if there is a correlation between certain departments and better ratings. I will not include departments with only one review. This is not enough data to explain the trend.
#
# SQL Features Used: CTE

# %%
# %%sql
# WITH InstructorDifficulty AS (
#     SELECT
#         t.InstructorID,
#         rr.Instructor,
#         rr.Department,
#         c.Subject,
#         rr.difficulty,
#         rr.Rating,
#         rr.CountRatings
#     FROM rmp_ratings rr
#     JOIN teachers t
#         ON rr.InstructorID = t.InstructorID
#     JOIN classes c
#         ON t.InstructorID = c.InstructorID
#     GROUP BY Instructor
#     ORDER BY rr.Rating DESC, Difficulty ASC
# )
# SELECT
#     Department,
#     ROUND(AVG(difficulty),2) AS AvgDifficulty,
#     ROUND(AVG(Rating),2) AS AvgRating,
#     COUNT(CountRatings) AS CountRatings
# FROM InstructorDifficulty
# GROUP BY Department
# HAVING COUNT(CountRatings) >= 2
# ORDER BY COUNT(CountRatings)DESC, ROUND(AVG(Rating),2) DESC, ROUND(AVG(Difficulty),2) DESC;
# Out:
#  * mysql://admin:***@isba-dev-01.cj5u8akyr9fw.us-east-1.rds.amazonaws.com/RMPproject
# 44 rows affected.
# [('Film & Television', 2.3, 3.8, 24),
#  ('Communication Studies', 2.38, 4.24, 22),
#  ('Business', 1.96, 3.02, 18),
#  ('Mathematics', 2.51, 3.45, 15),
#  ('Philosophy', 2.9, 3.64, 14),
#  ('Theater', 1.82, 3.98, 13),
#  ('Political Science', 2.91, 3.7, 13),
#  ('Theological Studies', 2.68, 3.48, 13),
#  ('Psychology', 3.48, 3.42, 13),
#  ('Economics', 2.95, 3.42, 13),
#  ('English', 2.37, 3.57, 12),
#  ('History', 2.62, 3.32, 12),
#  ('Chemistry', 3.0, 3.67, 11),
#  ('Film', 2.06, 3.66, 11),
#  ('Biology', 3.55, 3.51, 11),
#  ('Music', 2.52, 4.17, 9),
#  ('Theology', 2.72, 4.15, 8),
#  ('Marketing', 2.21, 4.39, 7),
#  ('Education', 2.86, 4.3, 7),
#  ('Accounting', 3.8, 3.46, 7),
#  ('African-American Studies', 1.31, 2.5, 7),
#  ('Sociology', 2.58, 4.4, 6),
#  ('Fine Arts', 2.83, 3.78, 6),
#  ('Computer Science', 3.77, 3.62, 6),
#  ('Finance', 3.08, 2.82, 6),
#  ('Art & Art History', 1.68, 1.98, 6),
#  ("Women's Studies", 2.9, 4.53, 4),
#  ('Physics', 2.82, 4.3, 4),
#  ('Dance', 1.65, 3.97, 4),
#  ('Engineering', 2.08, 3.08, 4),
#  ('Environmental Science', 2.47, 4.17, 3),
#  ('Management', 2.3, 4.07, 3),
#  ('Film amp Television', 2.23, 3.8, 3),
#  ('Entrepreneurship', 3.83, 3.73, 3),
#  ('Computer Information Systems', 3.0, 3.57, 3),
#  ('Health Sciences', 2.83, 3.57, 3),
#  ('Classics', 1.97, 2.73, 3),
#  ('Chinese', 3.0, 5.0, 2),
#  ('Modern Languages & Literatures', 3.5, 4.65, 2),
#  ('Chicano Studies', 3.3, 4.3, 2),
#  ('Asian Pacific American Studies', 3.15, 4.15, 2),
#  ('Ethnic Studies', 2.9, 3.75, 2),
#  ('Languages', 2.85, 3.55, 2),
#  ('American Studies', 3.0, 3.5, 2)]

# %% [markdown]
# I think it is interesting that departments that have the highest ratings are relatively difficult. I expected to see that the higher the rating, the easier the subject, however there is not a clear relationship here. This would be interesting to visualize. I expect if RMP was able to add more professors to the software, we may see changes in the results.
